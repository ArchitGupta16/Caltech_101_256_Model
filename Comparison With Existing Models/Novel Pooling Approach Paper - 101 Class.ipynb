# %%
import os
import time
import math
import random
import subprocess

from tqdm import tqdm
from glob import glob
from pathlib import Path
from tabulate import tabulate
from shutil import copy, copytree
from typing import Optional, Dict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score


import tensorflow as tf
from keras import layers
import keras.backend as K
from keras.layers import *
from keras.models import Model
from keras.optimizers import Adam
# from keras.utils import plot_model
from tensorflow.keras.utils import plot_model
from keras.preprocessing import image
from keras.applications import Xception
from keras.callbacks import EarlyStopping
from keras.metrics import Precision, Recall, AUC
# Out:
# 2024-08-04 09:02:20.141171: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 09:02:20.141234: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 09:02:20.142869: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# !wget https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# !unzip /kaggle/working/caltech-101.zip
# !mkdir data
# !tar -xf /kaggle/working/caltech-101/101_ObjectCategories.tar.gz -C /kaggle/working/data
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# --2024-08-04 09:02:24--  https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/47/20/fc77-d78a-4c50-81c9-d47c2004df45/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dcaltech-101.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20240804%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240804T090224Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=1f37726823cdc988a9b789943647b66a364ed7f522e8b9def72d9dc390d4cc0d [following]
# --2024-08-04 09:02:24--  https://s3.us-west-2.amazonaws.com/caltechdata/47/20/fc77-d78a-4c50-81c9-d47c2004df45/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dcaltech-101.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20240804%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20240804T090224Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=1f37726823cdc988a9b789943647b66a364ed7f522e8b9def72d9dc390d4cc0d
# Resolving s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)... 52.92.164.248, 52.218.185.96, 52.92.185.248, ...
# Connecting to s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)|52.92.164.248|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137414764 (131M) [application/octet-stream]
# Saving to: 'caltech-101.zip.1'
#
# caltech-101.zip.1   100%[===================>] 131.05M  38.2MB/s    in 3.8s
#
# 2024-08-04 09:02:28 (34.2 MB/s) - 'caltech-101.zip.1' saved [137414764/137414764]
#
# Archive:  /kaggle/working/caltech-101.zip
# replace __MACOSX/._caltech-101? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C
# mkdir: cannot create directory 'data': File exists

# %%
data_path = Path(r"/kaggle/working/data/101_ObjectCategories") # for kaggle
# data_path = Path(r"/content/data/101_ObjectCategories") # for colab

# %%
def count_images_per_class(path):
    """
    Prints the number of images in each class in the dataset.

    Parameters:
    -----------
    path: str
        A string representing the path to the data.

    Returns:
    --------
    None. Prints the number of images in each class to console.
    """

    # Printing the header for the output.
    print(f'{"Classes":>22} | {"Images":^6}')
    print("="*40)

    # Looping through each folder in the data path.
    for folder in os.listdir(path):

        # Counting the number of files in the current folder.
        sample_size = len(os.listdir(path / folder))

        # Printing the folder name and the number of files in it.
        print(f"{folder.strip():<23s}|{sample_size}")

# Call the function with the data path as an argument
count_images_per_class(data_path)
# Out:
#                Classes | Images
# ========================================
# scorpion               |84
# crayfish               |70
# inline_skate           |31
# lotus                  |66
# chair                  |62
# cougar_body            |47
# yin_yang               |60
# windsor_chair          |56
# kangaroo               |86
# okapi                  |39
# strawberry             |35
# joshua_tree            |64
# crocodile              |50
# car_side               |123
# umbrella               |75
# flamingo_head          |45
# rooster                |49
# ceiling_fan            |47
# mayfly                 |40
# hedgehog               |54
# headphone              |42
# euphonium              |64
# wild_cat               |34
# saxophone              |40
# stapler                |45
# garfield               |34
# Leopards               |200
# barrel                 |47
# soccer_ball            |64
# Faces_easy             |435
# lobster                |41
# helicopter             |88
# beaver                 |46
# ewer                   |85
# wrench                 |39
# chandelier             |107
# rhino                  |59
# scissors               |39
# electric_guitar        |75
# menorah                |87
# revolver               |82
# cup                    |57
# pyramid                |57
# ibis                   |80
# metronome              |32
# ferry                  |67
# grand_piano            |99
# gerenuk                |34
# flamingo               |67
# sunflower              |85
# Motorbikes             |798
# snoopy                 |35
# crocodile_head         |51
# pigeon                 |45
# BACKGROUND_Google      |468
# watch                  |239
# hawksbill              |100
# emu                    |53
# starfish               |86
# water_lilly            |37
# brontosaurus           |43
# dollar_bill            |52
# camera                 |50
# pagoda                 |47
# stegosaurus            |59
# ketch                  |114
# accordion              |55
# dalmatian              |67
# lamp                   |61
# bass                   |54
# buddha                 |85
# mandolin               |43
# airplanes              |800
# crab                   |73
# trilobite              |86
# platypus               |34
# anchor                 |42
# nautilus               |55
# Faces                  |435
# bonsai                 |128
# dolphin                |65
# cellphone              |59
# cougar_face            |69
# minaret                |76
# schooner               |63
# wheelchair             |59
# octopus                |35
# brain                  |98
# laptop                 |81
# tick                   |49
# elephant               |64
# butterfly              |91
# llama                  |78
# stop_sign              |64
# pizza                  |53
# dragonfly              |68
# ant                    |42
# gramophone             |51
# panda                  |38
# sea_horse              |57
# binocular              |33
# cannon                 |43

# %%
 def prepare_data(path: str, b_size: int) -> tuple:
    """Prepares training, validation, and test dataframes along with their respective steps.

    Args:
        path (str): The path to the directory containing the data.
        b_size (int): The batch size for training.

    Returns:
        tuple: A tuple containing the training dataframe, validation dataframe, test dataframe,
        training steps, validation steps, and test steps.
    """
    file_paths = []
    labels = []

    for claass in sorted(os.listdir(path)):
        c_pth = os.path.join(path, claass)

        for file in os.listdir(c_pth):
            file_path = os.path.join(c_pth, file)
            file_paths.append(file_path)
            labels.append(claass)

    print(f"Files: {len(file_paths)}\nLabels: {len(labels)}\n")

    files_series = pd.Series(file_paths, name="file_paths")
    labels_series = pd.Series(labels, name="labels")

    d = pd.concat([files_series, labels_series], axis=1)

    train_d, test_data_d = train_test_split(d, test_size=.2, stratify=d.labels, random_state=81)
    train_d, valid_d = train_test_split(train_d, test_size=.2, stratify=train_d.labels, random_state=81)

    print(f"Training Data: {train_d.shape[0]} samples\nTesting Data: {test_data_d.shape[0]} samples\nValidation Data: {valid_d.shape[0]} samples\n")

    return d, labels, train_d, valid_d, test_data_d

BATCH_SIZE = 6
df, labels, train_df, valid_df, test_df = prepare_data(data_path, BATCH_SIZE)
# Out:
# Files: 9145
# Labels: 9145
#
# Training Data: 5852 samples
# Testing Data: 1829 samples
# Validation Data: 1464 samples

# %%
def create_counts_table(d, test_d, train_d, valid_d):
    # Creating lists of the "labels" column from the data frames.
    df_labels = d["labels"]
    test_labels = test_d["labels"]
    train_labels = train_d["labels"]
    valid_labels = valid_d["labels"]

    # Printing the header for the output.
    print(f'{"Class":>19} | {"Test":^4} | {"Train":^5} | {"Valid":^5}')
    print("="*50)

    # Looping through each unique class in the "labels" column.
    for c in df_labels.unique():

        # Counting the number of times the current class appears in each data frame.
        test_count = list(test_labels).count(c)
        train_count = list(train_labels).count(c)
        valid_count = list(valid_labels).count(c)

        # Printing the class name and the counts for each data frame.
        print(f"{c:>19} | {test_count:^4} | {train_count:^5} | {valid_count}")

create_counts_table(df, test_df, train_df, valid_df)
# Out:
#               Class | Test | Train | Valid
# ==================================================
#   BACKGROUND_Google |  94  |  299  | 75
#               Faces |  87  |  278  | 70
#          Faces_easy |  87  |  278  | 70
#            Leopards |  40  |  128  | 32
#          Motorbikes | 160  |  510  | 128
#           accordion |  11  |  35   | 9
#           airplanes | 160  |  512  | 128
#              anchor |  8   |  27   | 7
#                 ant |  8   |  27   | 7
#              barrel |  9   |  30   | 8
#                bass |  11  |  34   | 9
#              beaver |  9   |  30   | 7
#           binocular |  7   |  21   | 5
#              bonsai |  26  |  82   | 20
#               brain |  20  |  62   | 16
#        brontosaurus |  9   |  27   | 7
#              buddha |  17  |  54   | 14
#           butterfly |  18  |  58   | 15
#              camera |  10  |  32   | 8
#              cannon |  9   |  27   | 7
#            car_side |  25  |  78   | 20
#         ceiling_fan |  9   |  30   | 8
#           cellphone |  12  |  38   | 9
#               chair |  12  |  40   | 10
#          chandelier |  21  |  69   | 17
#         cougar_body |  9   |  30   | 8
#         cougar_face |  14  |  44   | 11
#                crab |  15  |  46   | 12
#            crayfish |  14  |  45   | 11
#           crocodile |  10  |  32   | 8
#      crocodile_head |  10  |  33   | 8
#                 cup |  11  |  37   | 9
#           dalmatian |  13  |  43   | 11
#         dollar_bill |  10  |  34   | 8
#             dolphin |  13  |  42   | 10
#           dragonfly |  14  |  43   | 11
#     electric_guitar |  15  |  48   | 12
#            elephant |  13  |  41   | 10
#                 emu |  11  |  34   | 8
#           euphonium |  13  |  41   | 10
#                ewer |  17  |  54   | 14
#               ferry |  13  |  43   | 11
#            flamingo |  13  |  43   | 11
#       flamingo_head |  9   |  29   | 7
#            garfield |  7   |  22   | 5
#             gerenuk |  7   |  22   | 5
#          gramophone |  10  |  33   | 8
#         grand_piano |  20  |  63   | 16
#           hawksbill |  20  |  64   | 16
#           headphone |  8   |  27   | 7
#            hedgehog |  11  |  34   | 9
#          helicopter |  17  |  57   | 14
#                ibis |  16  |  51   | 13
#        inline_skate |  6   |  20   | 5
#         joshua_tree |  13  |  41   | 10
#            kangaroo |  17  |  55   | 14
#               ketch |  23  |  73   | 18
#                lamp |  12  |  39   | 10
#              laptop |  16  |  52   | 13
#               llama |  16  |  50   | 12
#             lobster |  8   |  26   | 7
#               lotus |  13  |  42   | 11
#            mandolin |  9   |  27   | 7
#              mayfly |  8   |  26   | 6
#             menorah |  17  |  56   | 14
#           metronome |  6   |  21   | 5
#             minaret |  15  |  49   | 12
#            nautilus |  11  |  35   | 9
#             octopus |  7   |  22   | 6
#               okapi |  8   |  25   | 6
#              pagoda |  9   |  30   | 8
#               panda |  8   |  24   | 6
#              pigeon |  9   |  29   | 7
#               pizza |  11  |  34   | 8
#            platypus |  7   |  22   | 5
#             pyramid |  11  |  37   | 9
#            revolver |  16  |  53   | 13
#               rhino |  12  |  38   | 9
#             rooster |  10  |  31   | 8
#           saxophone |  8   |  26   | 6
#            schooner |  13  |  40   | 10
#            scissors |  8   |  25   | 6
#            scorpion |  17  |  54   | 13
#           sea_horse |  11  |  37   | 9
#              snoopy |  7   |  22   | 6
#         soccer_ball |  13  |  41   | 10
#             stapler |  9   |  29   | 7
#            starfish |  17  |  55   | 14
#         stegosaurus |  12  |  38   | 9
#           stop_sign |  13  |  41   | 10
#          strawberry |  7   |  22   | 6
#           sunflower |  17  |  54   | 14
#                tick |  10  |  31   | 8
#           trilobite |  17  |  55   | 14
#            umbrella |  15  |  48   | 12
#               watch |  48  |  153  | 38
#         water_lilly |  7   |  24   | 6
#          wheelchair |  12  |  38   | 9
#            wild_cat |  7   |  22   | 5
#       windsor_chair |  11  |  36   | 9
#              wrench |  8   |  25   | 6
#            yin_yang |  12  |  38   | 10

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def load_data(df, b_size=BATCH_SIZE, shuffle=True, random_state=81, workers=1):
    generator = ImageDataGenerator(
        rescale=1 / 255.,
        # Add more augmentation parameters if needed
    )

    data = generator.flow_from_dataframe(
        df,
        x_col="file_paths",
        y_col="labels",
        target_size=(224, 224),
        class_mode="categorical",
        shuffle=shuffle,
        batch_size=b_size,
        seed=random_state,
        workers=workers
    )

    # Print a warning for invalid filenames
    invalid_filenames = df.loc[~df['file_paths'].isin(data.filenames), 'file_paths']
    if not invalid_filenames.empty:
        print("Warning: Invalid filenames found and will be ignored:", invalid_filenames.tolist())

    return data

# Load the training, validation, and test data with consistent random_state
train_data = load_data(train_df)
valid_data = load_data(valid_df, shuffle=False)
test_data = load_data(test_df, shuffle=False)
# Out:
# Found 5852 validated image filenames belonging to 102 classes.
# Found 1463 validated image filenames belonging to 102 classes.
# Warning: Invalid filenames found and will be ignored: ['/kaggle/working/data/101_ObjectCategories/BACKGROUND_Google/tmp']
# Found 1829 validated image filenames belonging to 102 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="file_paths". These filename(s) will be ignored.
#   warnings.warn(

# %%
import tensorflow.keras.backend as K
def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.

    Returns:
        tuple: A tuple of the metrics: (recall, precision, f1_score, auc, sensitivity, specificity, mcc).
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """
        Calculates the F1 score.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: F1 score.
        """
        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """
        Calculates the specificity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Specificity.
        """
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """
        Calculates the sensitivity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Sensitivity.
        """
        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Matthews correlation coefficient.
        """
        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """
        Calculates the number of true positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true positives.
        """
        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """
        Calculates the number of false positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false positives.
        """
        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """
        Calculates the number of false negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false negatives.
        """
        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """
        Calculates the number of true negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true negatives.
        """
        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """
        Calculates the components of the confusion matrix.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            tuple: A tuple containing the components of the confusion matrix: (y_pred_pos, y_pred_neg, y_pos, y_neg).
        """
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def conv_bn(x, filters, kernel_size, strides):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=6.0)(x)
    return x

def conv_1x1_bn(x, filters):
    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=6.0)(x)
    return x

def inverted_res_block(x, filters, stride, expand_ratio):
    input_shape = tf.keras.backend.int_shape(x)
    in_channels = input_shape[-1]
    hidden_dim = in_channels * expand_ratio
    use_res_connect = (stride == 1 and in_channels == filters)

    residual_input = x  # Renamed the input to avoid conflict with reserved keyword

    if expand_ratio != 1:
        x = conv_1x1_bn(x, hidden_dim)

    x = layers.DepthwiseConv2D(kernel_size=3, strides=stride, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU(max_value=6.0)(x)

    x = layers.Conv2D(filters, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if use_res_connect:
        return layers.add([x, residual_input])
    else:
        return x

def MobileNetV2(input_shape=(224, 224, 3), n_class=1000, width_mult=1.0):
    input_tensor = layers.Input(shape=input_shape)
    x = conv_bn(input_tensor, int(32 * width_mult), 3, 2)

    inverted_residual_setting = [
        # t, c, n, s
        [1, 16, 1, 1],
        [6, 24, 2, 2],
        [6, 32, 3, 2],
        [6, 64, 4, 2],
        [6, 96, 3, 1],
        [6, 160, 3, 2],
        [6, 320, 1, 1],
    ]

    for t, c, n, s in inverted_residual_setting:
        out_channels = int(c * width_mult)
        for i in range(n):
            if i == 0:
                x = inverted_res_block(x, out_channels, s, t)
            else:
                x = inverted_res_block(x, out_channels, 1, t)

    last_channel = int(1280 * width_mult) if width_mult > 1.0 else 1280
    x = conv_1x1_bn(x, last_channel)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.2)(x)
    output = layers.Dense(n_class, activation='softmax')(x)

    model = models.Model(input_tensor, output)
    return model

# %%
model = MobileNetV2(input_shape=(224, 224, 3), n_class=102)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 112, 112,  │        864 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ conv2d_70[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_70 (ReLU)     │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_34 │ (None, 112, 112,  │        288 │ re_lu_70[0][0]    │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_71 (ReLU)     │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 112, 112,  │        512 │ re_lu_71[0][0]    │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │         64 │ conv2d_71[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 112, 112,  │      1,536 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 112, 112,  │        384 │ conv2d_72[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_72 (ReLU)     │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_35 │ (None, 56, 56,    │        864 │ re_lu_72[0][0]    │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_73 (ReLU)     │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 56, 56,    │      2,304 │ re_lu_73[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │         96 │ conv2d_73[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 56, 56,    │      3,456 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ conv2d_74[0][0]   │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_74 (ReLU)     │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_36 │ (None, 56, 56,    │      1,296 │ re_lu_74[0][0]    │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_75 (ReLU)     │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 56, 56,    │      3,456 │ re_lu_75[0][0]    │
# │                     │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │         96 │ conv2d_75[0][0]   │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 24)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 56, 56,    │      3,456 │ add_20[0][0]      │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        576 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_76 (ReLU)     │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_37 │ (None, 28, 28,    │      1,296 │ re_lu_76[0][0]    │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        576 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_77 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 28, 28,    │      4,608 │ re_lu_77[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 28, 28,    │      6,144 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_78[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_78 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_38 │ (None, 28, 28,    │      1,728 │ re_lu_78[0][0]    │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_79 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_79 (Conv2D)  │ (None, 28, 28,    │      6,144 │ re_lu_79[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_79[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_80 (Conv2D)  │ (None, 28, 28,    │      6,144 │ add_21[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_80[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_80 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_39 │ (None, 28, 28,    │      1,728 │ re_lu_80[0][0]    │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_81 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_81 (Conv2D)  │ (None, 28, 28,    │      6,144 │ re_lu_81[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_81[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ add_21[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_82 (Conv2D)  │ (None, 28, 28,    │      6,144 │ add_22[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        768 │ conv2d_82[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_82 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_40 │ (None, 14, 14,    │      1,728 │ re_lu_82[0][0]    │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        768 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_83 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_83 (Conv2D)  │ (None, 14, 14,    │     12,288 │ re_lu_83[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_83[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_84 (Conv2D)  │ (None, 14, 14,    │     24,576 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_84[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_84 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_41 │ (None, 14, 14,    │      3,456 │ re_lu_84[0][0]    │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_85 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_85 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu_85[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_85[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_86 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_23[0][0]      │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_86[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_86 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_42 │ (None, 14, 14,    │      3,456 │ re_lu_86[0][0]    │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_87 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_87 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu_87[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_87[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ add_23[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_24[0][0]      │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_88[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_88 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_43 │ (None, 14, 14,    │      3,456 │ re_lu_88[0][0]    │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_89 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_89 (Conv2D)  │ (None, 14, 14,    │     24,576 │ re_lu_89[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        256 │ conv2d_89[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 14, 14,    │     24,576 │ add_25[0][0]      │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ conv2d_90[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_90 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_44 │ (None, 14, 14,    │      3,456 │ re_lu_90[0][0]    │
# │ (DepthwiseConv2D)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,536 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_91 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_91 (Conv2D)  │ (None, 14, 14,    │     36,864 │ re_lu_91[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_91[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 14, 14,    │     55,296 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_92[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_92 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_45 │ (None, 14, 14,    │      5,184 │ re_lu_92[0][0]    │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_93 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_93 (Conv2D)  │ (None, 14, 14,    │     55,296 │ re_lu_93[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_93[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 14, 14,    │     55,296 │ add_26[0][0]      │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_94[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_94 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_46 │ (None, 14, 14,    │      5,184 │ re_lu_94[0][0]    │
# │ (DepthwiseConv2D)   │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_95 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_95 (Conv2D)  │ (None, 14, 14,    │     55,296 │ re_lu_95[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        384 │ conv2d_95[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 14, 14,    │     55,296 │ add_27[0][0]      │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      2,304 │ conv2d_96[0][0]   │
# │ (BatchNormalizatio… │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_96 (ReLU)     │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │                     │ 576)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_47 │ (None, 7, 7, 576) │      5,184 │ re_lu_96[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 576) │      2,304 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_97 (ReLU)     │ (None, 7, 7, 576) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_97 (Conv2D)  │ (None, 7, 7, 160) │     92,160 │ re_lu_97[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_97[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 7, 7, 960) │    153,600 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_98[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_98 (ReLU)     │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_48 │ (None, 7, 7, 960) │      8,640 │ re_lu_98[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_99 (ReLU)     │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_99 (Conv2D)  │ (None, 7, 7, 160) │    153,600 │ re_lu_99[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_99[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 7, 7, 160) │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 7, 7, 960) │    153,600 │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_100[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_100 (ReLU)    │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_49 │ (None, 7, 7, 960) │      8,640 │ re_lu_100[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_101 (ReLU)    │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_101 (Conv2D) │ (None, 7, 7, 160) │    153,600 │ re_lu_101[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 160) │        640 │ conv2d_101[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 7, 7, 160) │          0 │ batch_normalizat… │
# │                     │                   │            │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 7, 7, 960) │    153,600 │ add_29[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ conv2d_102[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_102 (ReLU)    │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_50 │ (None, 7, 7, 960) │      8,640 │ re_lu_102[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 960) │      3,840 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_103 (ReLU)    │ (None, 7, 7, 960) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_103 (Conv2D) │ (None, 7, 7, 320) │    307,200 │ re_lu_103[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 320) │      1,280 │ conv2d_103[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 7, 7,      │    409,600 │ batch_normalizat… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7,      │      5,120 │ conv2d_104[0][0]  │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_104 (ReLU)    │ (None, 7, 7,      │          0 │ batch_normalizat… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1280)      │          0 │ re_lu_104[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 1280)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 102)       │    130,662 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,388,646 (9.11 MB)
#  Trainable params: 2,354,534 (8.98 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
plot_model(model, to_file='modified_model.png', show_shapes=True, show_layer_activations=True)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs=None):
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch, logs=None):
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch, logs=None):
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs=None):
        """Calculate total training time."""
        self.total_train_time = time.perf_counter() - self.train_start_time

time_callback = TimeCallback()

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
from keras.callbacks import LearningRateScheduler

learningRate = 1e-4
decayRate = 0.97

def lr_schedule(epoch):
    if epoch < 2:
        return learningRate
    else:
        return learningRate * decayRate ** epoch

learning_callback = LearningRateScheduler(lr_schedule)

# %%
custom_metrics = list(create_metrics())
custom_metrics.append("accuracy")

model.compile(
    optimizer=Adam(learning_rate=learningRate),
    loss='categorical_crossentropy',
    metrics=custom_metrics
)

history = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=50,
    callbacks=[time_callback, early_stopping]
)
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#   3/976 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.0000e+00 - auc_2: 0.2692 - f1_score: 0.0000e+00 - loss: 5.2868 - mcc: 0.0000e+00 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - sensitivity: 0.0000e+00 - specificity: 1.0000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722762325.234003     929 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1722762325.298264     929 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 914/976 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.1413 - auc_2: 0.6899 - f1_score: 0.0439 - loss: 4.1761 - mcc: 0.0595 - precision_2: 0.5640 - recall_2: 0.0264 - sensitivity: 0.0264 - specificity: 0.9999
# W0000 00:00:1722762377.435697     930 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.1439 - auc_2: 0.6925 - f1_score: 0.0473 - loss: 4.1613 - mcc: 0.0641 - precision_2: 0.5767 - recall_2: 0.0286 - sensitivity: 0.0286 - specificity: 0.9999
# W0000 00:00:1722762383.855625     928 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1722762390.755562     931 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 120s 67ms/step - accuracy: 0.1439 - auc_2: 0.6926 - f1_score: 0.0474 - loss: 4.1611 - mcc: 0.0642 - precision_2: 0.5769 - recall_2: 0.0286 - sensitivity: 0.0286 - specificity: 0.9999 - val_accuracy: 0.2673 - val_auc_2: 0.7995 - val_f1_score: 0.2312 - val_loss: 3.4657 - val_mcc: 0.2842 - val_precision_2: 0.7950 - val_recall_2: 0.1511 - val_sensitivity: 0.1510 - val_specificity: 0.9996
# Epoch 2/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 33ms/step - accuracy: 0.2422 - auc_2: 0.8024 - f1_score: 0.1833 - loss: 3.5258 - mcc: 0.2399 - precision_2: 0.7921 - recall_2: 0.1135 - sensitivity: 0.1135 - specificity: 0.9997 - val_accuracy: 0.3267 - val_auc_2: 0.8436 - val_f1_score: 0.3318 - val_loss: 3.1520 - val_mcc: 0.3754 - val_precision_2: 0.6908 - val_recall_2: 0.2351 - val_sensitivity: 0.2350 - val_specificity: 0.9990
# Epoch 3/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.3258 - auc_2: 0.8604 - f1_score: 0.2881 - loss: 3.0612 - mcc: 0.3563 - precision_2: 0.8510 - recall_2: 0.1868 - sensitivity: 0.1866 - specificity: 0.9997 - val_accuracy: 0.3705 - val_auc_2: 0.8872 - val_f1_score: 0.3784 - val_loss: 2.7815 - val_mcc: 0.4340 - val_precision_2: 0.8269 - val_recall_2: 0.2645 - val_sensitivity: 0.2643 - val_specificity: 0.9995
# Epoch 4/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - accuracy: 0.3447 - auc_2: 0.8859 - f1_score: 0.3127 - loss: 2.8771 - mcc: 0.3776 - precision_2: 0.8694 - recall_2: 0.2082 - sensitivity: 0.2081 - specificity: 0.9997 - val_accuracy: 0.4074 - val_auc_2: 0.8958 - val_f1_score: 0.4460 - val_loss: 2.5737 - val_mcc: 0.4912 - val_precision_2: 0.7983 - val_recall_2: 0.3274 - val_sensitivity: 0.3273 - val_specificity: 0.9992
# Epoch 5/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.4112 - auc_2: 0.9109 - f1_score: 0.3651 - loss: 2.5826 - mcc: 0.4315 - precision_2: 0.8960 - recall_2: 0.2492 - sensitivity: 0.2486 - specificity: 0.9997 - val_accuracy: 0.4388 - val_auc_2: 0.9157 - val_f1_score: 0.4746 - val_loss: 2.3937 - val_mcc: 0.5249 - val_precision_2: 0.8519 - val_recall_2: 0.3500 - val_sensitivity: 0.3499 - val_specificity: 0.9994
# Epoch 6/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - accuracy: 0.4629 - auc_2: 0.9302 - f1_score: 0.4226 - loss: 2.2979 - mcc: 0.4852 - precision_2: 0.9050 - recall_2: 0.2976 - sensitivity: 0.2976 - specificity: 0.9997 - val_accuracy: 0.4771 - val_auc_2: 0.9210 - val_f1_score: 0.4800 - val_loss: 2.2954 - val_mcc: 0.5258 - val_precision_2: 0.8210 - val_recall_2: 0.3575 - val_sensitivity: 0.3574 - val_specificity: 0.9992
# Epoch 7/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.5027 - auc_2: 0.9510 - f1_score: 0.4611 - loss: 2.0652 - mcc: 0.5201 - precision_2: 0.9203 - recall_2: 0.3325 - sensitivity: 0.3325 - specificity: 0.9997 - val_accuracy: 0.4942 - val_auc_2: 0.9273 - val_f1_score: 0.5290 - val_loss: 2.1542 - val_mcc: 0.5679 - val_precision_2: 0.8354 - val_recall_2: 0.4060 - val_sensitivity: 0.4060 - val_specificity: 0.9992
# Epoch 8/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.5346 - auc_2: 0.9575 - f1_score: 0.4869 - loss: 1.9049 - mcc: 0.5442 - precision_2: 0.9376 - recall_2: 0.3561 - sensitivity: 0.3561 - specificity: 0.9998 - val_accuracy: 0.5373 - val_auc_2: 0.9378 - val_f1_score: 0.5615 - val_loss: 1.8877 - val_mcc: 0.5940 - val_precision_2: 0.8303 - val_recall_2: 0.4416 - val_sensitivity: 0.4415 - val_specificity: 0.9991
# Epoch 9/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - accuracy: 0.5754 - auc_2: 0.9684 - f1_score: 0.5255 - loss: 1.7016 - mcc: 0.5747 - precision_2: 0.9232 - recall_2: 0.3932 - sensitivity: 0.3932 - specificity: 0.9997 - val_accuracy: 0.5578 - val_auc_2: 0.9333 - val_f1_score: 0.5707 - val_loss: 1.9386 - val_mcc: 0.5955 - val_precision_2: 0.7965 - val_recall_2: 0.4655 - val_sensitivity: 0.4653 - val_specificity: 0.9988
# Epoch 10/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.6020 - auc_2: 0.9744 - f1_score: 0.5658 - loss: 1.5538 - mcc: 0.6137 - precision_2: 0.9404 - recall_2: 0.4279 - sensitivity: 0.4277 - specificity: 0.9997 - val_accuracy: 0.5858 - val_auc_2: 0.9439 - val_f1_score: 0.6014 - val_loss: 1.7547 - val_mcc: 0.6278 - val_precision_2: 0.8386 - val_recall_2: 0.4901 - val_sensitivity: 0.4900 - val_specificity: 0.9991
# Epoch 11/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.6633 - auc_2: 0.9803 - f1_score: 0.6116 - loss: 1.3587 - mcc: 0.6505 - precision_2: 0.9408 - recall_2: 0.4780 - sensitivity: 0.4779 - specificity: 0.9997 - val_accuracy: 0.6029 - val_auc_2: 0.9516 - val_f1_score: 0.6127 - val_loss: 1.6443 - val_mcc: 0.6417 - val_precision_2: 0.8665 - val_recall_2: 0.4969 - val_sensitivity: 0.4969 - val_specificity: 0.9992
# Epoch 12/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.6928 - auc_2: 0.9837 - f1_score: 0.6452 - loss: 1.2161 - mcc: 0.6815 - precision_2: 0.9490 - recall_2: 0.5146 - sensitivity: 0.5144 - specificity: 0.9997 - val_accuracy: 0.6083 - val_auc_2: 0.9515 - val_f1_score: 0.6240 - val_loss: 1.6387 - val_mcc: 0.6444 - val_precision_2: 0.8242 - val_recall_2: 0.5222 - val_sensitivity: 0.5221 - val_specificity: 0.9989
# Epoch 13/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.7380 - auc_2: 0.9872 - f1_score: 0.6839 - loss: 1.0550 - mcc: 0.7147 - precision_2: 0.9513 - recall_2: 0.5586 - sensitivity: 0.5588 - specificity: 0.9997 - val_accuracy: 0.6268 - val_auc_2: 0.9481 - val_f1_score: 0.6455 - val_loss: 1.6099 - val_mcc: 0.6670 - val_precision_2: 0.8525 - val_recall_2: 0.5414 - val_sensitivity: 0.5414 - val_specificity: 0.9991
# Epoch 14/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.7679 - auc_2: 0.9913 - f1_score: 0.7155 - loss: 0.9305 - mcc: 0.7388 - precision_2: 0.9420 - recall_2: 0.6020 - sensitivity: 0.6019 - specificity: 0.9996 - val_accuracy: 0.6418 - val_auc_2: 0.9520 - val_f1_score: 0.6654 - val_loss: 1.5230 - val_mcc: 0.6832 - val_precision_2: 0.8455 - val_recall_2: 0.5687 - val_sensitivity: 0.5686 - val_specificity: 0.9990
# Epoch 15/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.8083 - auc_2: 0.9944 - f1_score: 0.7594 - loss: 0.7959 - mcc: 0.7781 - precision_2: 0.9563 - recall_2: 0.6497 - sensitivity: 0.6497 - specificity: 0.9997 - val_accuracy: 0.6261 - val_auc_2: 0.9443 - val_f1_score: 0.6555 - val_loss: 1.5876 - val_mcc: 0.6694 - val_precision_2: 0.8137 - val_recall_2: 0.5673 - val_sensitivity: 0.5673 - val_specificity: 0.9987
# Epoch 16/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 32s 32ms/step - accuracy: 0.8240 - auc_2: 0.9948 - f1_score: 0.7725 - loss: 0.7109 - mcc: 0.7881 - precision_2: 0.9452 - recall_2: 0.6740 - sensitivity: 0.6740 - specificity: 0.9996 - val_accuracy: 0.6254 - val_auc_2: 0.9349 - val_f1_score: 0.6591 - val_loss: 1.6881 - val_mcc: 0.6740 - val_precision_2: 0.8171 - val_recall_2: 0.5680 - val_sensitivity: 0.5679 - val_specificity: 0.9987
# Epoch 17/50
# 976/976 ━━━━━━━━━━━━━━━━━━━━ 31s 32ms/step - accuracy: 0.8546 - auc_2: 0.9966 - f1_score: 0.8149 - loss: 0.5879 - mcc: 0.8255 - precision_2: 0.9516 - recall_2: 0.7326 - sensitivity: 0.7314 - specificity: 0.9996 - val_accuracy: 0.6391 - val_auc_2: 0.9454 - val_f1_score: 0.6651 - val_loss: 1.6008 - val_mcc: 0.6814 - val_precision_2: 0.8323 - val_recall_2: 0.5735 - val_sensitivity: 0.5735 - val_specificity: 0.9989

# %%
execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(time_callback.total_train_time // unit[0])
    avg_value = int(np.mean(time_callback.epoch_times) // unit[0])

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    time_callback.total_train_time -= total_value * unit[0]
    time_callback.epoch_times = [time - avg_value * unit[0] for time in time_callback.epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 10 minutes, 34 seconds, 455 milliseconds
# Average time per epoch: 37 seconds, 243 milliseconds

# %%
_ = model.evaluate(test_data)
# Out:
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6341 - auc_2: 0.9448 - f1_score: 0.6552 - loss: 1.5867 - mcc: 0.6715 - precision_2: 0.8199 - recall_2: 0.5625 - sensitivity: 0.5625 - specificity: 0.9988

# %%
def plot_metrics(history, metric_name_list, figure_size=(10, 6)):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        history: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot
        figure_size: a tuple specifying the size of the figure (width, height)

    Returns:
        None
    """
    # Check if history is a valid Keras History object
    if not isinstance(history, type(tf.keras.callbacks.History())):
        raise ValueError("Invalid Keras History object provided.")

    num_metrics = len(metric_name_list)

    # Create subplots
    figure, axes = plt.subplots(num_metrics, figsize=(figure_size[0], figure_size[1] * num_metrics))

    # Define x-axis range
    rng = range(1, len(history.history[metric_name_list[0]]) + 1)

    for ax, metric_name in zip(axes, metric_name_list):
        # Check if the metric exists in the history
        if metric_name not in history.history:
            raise ValueError(f"Metric '{metric_name}' not found in the training history.")

        metric = history.history[metric_name]
        v_metric = history.history.get(f"val_{metric_name}", None)

        # Plot training metric
        ax.plot(rng, metric, label=metric_name)

        # Plot validation metric if available
        if v_metric is not None:
            ax.plot(rng, v_metric, label=f"val_{metric_name}")

        ax.legend()
        ax.set_xlabel("Epochs")

        # Set y-axis label and title
        ylabel = metric_name.upper() if metric_name in ("auc", "mcc") else metric_name.capitalize()
        ax.set_ylabel(ylabel)
        ax.set_title(f"{ylabel} vs Epochs")

        # Set y-axis limits
        max_loss = max(max(metric), max(v_metric)) if v_metric is not None else max(metric)
        min_loss = min(min(metric), min(v_metric)) if v_metric is not None else min(metric)
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()
    plt.show()

metric_names = ["loss", "accuracy",  "f1_score",
                "specificity", "sensitivity", "mcc"]
plot_metrics(history, metric_names)
