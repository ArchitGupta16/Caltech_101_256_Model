# %%
import os
import time
import math
import subprocess

from tqdm import tqdm
from glob import glob
from pathlib import Path
from tabulate import tabulate
from typing import Optional, Dict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def download_and_extract(download_url, download_path, output_dir):
    try:
        check_dependencies()

        # Download the file without progress display
        subprocess.run(["wget", "-q", download_url, "-O", download_path], check=True)

        # Check if the download was successful before proceeding
        if os.path.exists(download_path):
            # Create the output directory
            os.makedirs(output_dir, exist_ok=True)

            # Extract the contents
            extract_command = ["tar", "-xf", download_path, "-C", output_dir]
            subprocess.run(extract_command, check=True)

            # Remove the tar file after extraction
            os.remove(download_path)
            print("Download and extraction completed successfully.")
        else:
            print("Error: Failed to download the dataset.")
    except subprocess.CalledProcessError as e:
        print(f"Error: {str(e)}")
        
def check_dependencies():
    try:
        subprocess.run(["wget", "--version"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True)
        subprocess.run(["tar", "--version"], stdout=subprocess.PIPE, stderr=subprocess.PIPE, check=True)
    except subprocess.CalledProcessError as e:
        print(f"Error: Dependency check failed. {e}")
        raise

# %%
# Variables
download_url = "https://data.caltech.edu/records/nyy15-4j048/files/256_ObjectCategories.tar"
download_path = "/kaggle/working/256_ObjectCategories.tar"
# download_path = "/content/256_ObjectCategories.tar" # colab
output_dir = "/kaggle/working/data"
# output_dir = "/content/data" # colab

# Function call
download_and_extract(download_url, download_path, output_dir)
# Out:
# Download and extraction completed successfully.

# %%
data_path = Path(r"/kaggle/working/data/256_ObjectCategories") # for kaggle
# data_path = Path(r"/content/data/256_ObjectCategories") # for colab

# %%
def count_images_per_class(path):
    """Prints the number of images in each class in the dataset."""
    print(f'{"Classes":>22} | {"Images":^6}')
    print("=" * 40)

    for folder in os.listdir(path):
        sample_size = len(os.listdir(path / folder))
        print(f"{folder.strip():<23s}|{sample_size}")

count_images_per_class(data_path)
# Out:
#                Classes | Images
# ========================================
# 032.cartman            |101
# 046.computer-monitor   |133
# 230.trilobite-101      |94
# 253.faces-easy-101     |435
# 214.teepee             |139
# 094.guitar-pick        |104
# 026.cake               |106
# 033.cd                 |102
# 018.bowling-pin        |101
# 099.harpsichord        |80
# 196.spaghetti          |104
# 235.umbrella-101       |114
# 249.yo-yo              |100
# 226.traffic-light      |99
# 233.tuning-fork        |100
# 185.skateboard         |103
# 001.ak47               |98
# 146.mountain-bike      |82
# 116.iguana             |107
# 202.steering-wheel     |97
# 037.chess-board        |120
# 220.toaster            |94
# 014.blimp              |86
# 247.xylophone          |92
# 051.cowboy-hat         |114
# 083.gas-pump           |95
# 255.tennis-shoes       |103
# 169.radio-telescope    |92
# 039.chopsticks         |85
# 087.goldfish           |93
# 123.ketch-101          |111
# 104.homer-simpson      |97
# 236.unicorn            |97
# 029.cannon             |103
# 188.smokestack         |88
# 166.praying-mantis     |92
# 070.fire-extinguisher  |84
# 020.brain-101          |83
# 221.tomato             |103
# 011.billiards          |278
# 124.killer-whale       |91
# 192.snowmobile         |112
# 071.fire-hydrant       |99
# 079.frisbee            |99
# 155.paperclip          |92
# 151.ostrich            |109
# 050.covered-wagon      |97
# 028.camel              |110
# 027.calculator         |100
# 239.washing-machine    |84
# 040.cockroach          |124
# 103.hibiscus           |111
# 085.goat               |112
# 215.telephone-box      |84
# 013.birdbath           |98
# 065.elk                |101
# 241.waterfall          |95
# 216.tennis-ball        |98
# 176.saddle             |110
# 078.fried-egg          |90
# 149.necktie            |103
# 008.bathtub            |232
# 152.owl                |120
# 048.conch              |103
# 161.photocopier        |103
# 005.baseball-glove     |148
# 158.penguin            |149
# 047.computer-mouse     |94
# 089.goose              |110
# 102.helicopter-101     |88
# 110.hourglass          |85
# 015.bonsai-101         |122
# 084.giraffe            |84
# 068.fern               |110
# 135.mailbox            |93
# 210.syringe            |111
# 088.golf-ball          |98
# 063.electric-guitar-101|122
# 232.t-shirt            |358
# 023.bulldozer          |110
# 250.zebra              |96
# 062.eiffel-tower       |83
# 081.frying-pan         |95
# 041.coffee-mug         |87
# 174.rotary-phone       |84
# 162.picnic-table       |91
# 143.minaret            |130
# 248.yarmulke           |84
# 125.knife              |101
# 090.gorilla            |212
# 206.sushi              |98
# 184.sheet-music        |84
# 164.porcupine          |101
# 127.laptop-101         |128
# 212.teapot             |136
# 225.tower-pisa         |90
# 101.head-phones        |138
# 213.teddy-bear         |101
# 012.binoculars         |216
# 197.speed-boat         |100
# 150.octopus            |111
# 129.leopards-101       |190
# 016.boom-box           |91
# 036.chandelier-101     |106
# 073.fireworks          |100
# 076.football-helmet    |84
# 120.joy-stick          |130
# 189.snail              |119
# 092.grapes             |201
# 030.canoe              |104
# 209.sword              |102
# 251.airplanes-101      |800
# 256.toad               |108
# 002.american-flag      |97
# 137.mars               |156
# 205.superman           |87
# 139.megaphone          |86
# 219.theodolite         |84
# 157.pci-card           |105
# 252.car-side-101       |116
# 144.minotaur           |82
# 195.soda-can           |87
# 243.welding-mask       |90
# 234.tweezer            |122
# 043.coin               |124
# 022.buddha-101         |97
# 098.harp               |100
# 203.stirrups           |91
# 154.palm-tree          |103
# 240.watch-101          |201
# 231.tripod             |112
# 053.desk-globe         |82
# 132.light-house        |190
# 038.chimp              |110
# 200.stained-glass      |100
# 054.diamond-ring       |118
# 072.fire-truck         |118
# 128.lathe              |105
# 009.bear               |102
# 115.ice-cream-cone     |88
# 100.hawksbill-101      |93
# 069.fighter-jet        |99
# 217.tennis-court       |105
# 186.skunk              |81
# 082.galaxy             |81
# 056.dog                |103
# 134.llama-101          |119
# 055.dice               |98
# 095.hamburger          |86
# 114.ibis-101           |120
# 198.spider             |109
# 003.backpack           |151
# 257.clutter            |827
# 034.centipede          |100
# 179.scorpion-101       |80
# 113.hummingbird        |116
# 168.raccoon            |140
# 105.horse              |270
# 108.hot-dog            |85
# 246.wine-bottle        |101
# 140.menorah-101        |89
# 117.ipod               |121
# 126.ladder             |242
# 049.cormorant          |106
# 060.duck               |87
# 227.treadmill          |147
# 057.dolphin-101        |106
# 121.kangaroo-101       |82
# 175.roulette-wheel     |83
# 131.lightbulb          |92
# 207.swan               |115
# 017.bowling-ball       |104
# 167.pyramid            |86
# 170.rainbow            |102
# 242.watermelon         |93
# 211.tambourine         |95
# 153.palm-pilot         |93
# 180.screwdriver        |102
# 075.floppy-disk        |83
# 183.sextant            |100
# 006.basketball-hoop    |90
# 138.mattress           |192
# 163.playing-card       |90
# 106.horseshoe-crab     |87
# 111.house-fly          |84
# 223.top-hat            |80
# 097.harmonica          |89
# 191.sneaker            |111
# 193.soccer-ball        |174
# 093.grasshopper        |112
# 080.frog               |116
# 019.boxing-glove       |124
# 208.swiss-army-knife   |109
# 244.wheelbarrow        |91
# 133.lightning          |136
# 145.motorbikes-101     |798
# 237.vcr                |90
# 059.drinking-straw     |83
# 025.cactus             |114
# 024.butterfly          |112
# 194.socks              |112
# 190.snake              |112
# 229.tricycle           |95
# 052.crab-101           |85
# 109.hot-tub            |156
# 187.skyscraper         |95
# 067.eyeglasses         |83
# 142.microwave          |107
# 172.revolver-101       |99
# 136.mandolin           |93
# 160.pez-dispenser      |83
# 165.pram               |88
# 091.grand-piano-101    |95
# 238.video-projector    |97
# 204.sunflower-101      |80
# 044.comet              |121
# 147.mushroom           |202
# 064.elephant-101       |131
# 122.kayak              |103
# 222.tombstone          |91
# 245.windmill           |91
# 031.car-tire           |90
# 199.spoon              |105
# 004.baseball-bat       |127
# 112.human-skeleton     |84
# 171.refrigerator       |84
# 035.cereal-box         |87
# 224.touring-bike       |110
# 074.flashlight         |115
# 086.golden-gate-bridge |80
# 061.dumb-bell          |102
# 201.starfish-101       |81
# 010.beer-mug           |94
# 107.hot-air-balloon    |89
# 159.people             |209
# 218.tennis-racket      |81
# 182.self-propelled-lawn-mower|120
# 156.paper-shredder     |96
# 066.ewer-101           |83
# 141.microscope         |117
# 042.coffin             |87
# 228.triceratops        |95
# 181.segway             |100
# 007.bat                |106
# 178.school-bus         |98
# 148.mussels            |174
# 254.greyhound          |95
# 045.computer-keyboard  |85
# 058.doorknob           |93
# 119.jesus-christ       |87
# 173.rifle              |106
# 118.iris               |108
# 130.license-plate      |91
# 077.french-horn        |92
# 096.hammock            |285
# 021.breadmaker         |142
# 177.saturn             |96

# %%
RANDOM_STATE = 81
TEST_SIZE = 0.1
VALIDATION_SPLIT = 0.2

def prepare_data(path, test_size=TEST_SIZE, random_state=RANDOM_STATE):
    """Prepares the training, validation, and test dataframes."""
    path = Path(path)
    if not path.is_dir():
        raise ValueError("Provided path is not a directory.")

    file_paths = []
    labels = []

    for class_dir in sorted(path.iterdir()):
        if class_dir.is_dir():
            class_name = class_dir.name.split(".")[1]

            files = list(class_dir.glob("*"))
            if not files:
                print(f"No files found in {class_dir}. Skipping.")
                continue

            class_labels = [class_name] * len(files)
            file_paths.extend(files)
            labels.extend(class_labels)

    print(f"Files: {len(file_paths)}\n"
          f"Labels: {len(labels)}\n")

    labels = pd.Series(labels, name='labels')
    df = pd.DataFrame({"file_paths": file_paths, "labels": labels})

    tr_df, te_df = train_test_split(df, test_size=test_size, stratify=df["labels"], random_state=random_state)
    tr_df, v_df = train_test_split(tr_df, test_size=VALIDATION_SPLIT, stratify=tr_df["labels"], random_state=random_state)

    print(f"Training Data: {tr_df.shape[0]} samples\n"
          f"Testing Data: {te_df.shape[0]} samples\n"
          f"Validation Data: {v_df.shape[0]} samples")

    return tr_df, v_df, te_df, df, labels

train_df, valid_df, test_df, df, labels = prepare_data(data_path)
# Out:
# Files: 30609
# Labels: 30609
#
# Training Data: 22038 samples
# Testing Data: 3061 samples
# Validation Data: 5510 samples
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
def create_counts_table(d, test_d, train_d, valid_d):
    """Creates and prints a table showing the distribution of classes."""
    df_labels = d["labels"]
    test_labels = test_d["labels"]
    train_labels = train_d["labels"]
    valid_labels = valid_d["labels"]

    print(f'{"Class":>19} | {"Test":^4} | {"Train":^5} | {"Valid":^5}')
    print("=" * 50)

    for c in df_labels.unique():
        test_count = list(test_labels).count(c)
        train_count = list(train_labels).count(c)
        valid_count = list(valid_labels).count(c)

        print(f"{c:>19} | {test_count:^4} | {train_count:^5} | {valid_count}")

create_counts_table(df, test_df, train_df, valid_df)
# Out:
#               Class | Test | Train | Valid
# ==================================================
#                ak47 |  10  |  70   | 18
#       american-flag |  10  |  70   | 17
#            backpack |  15  |  109  | 27
#        baseball-bat |  13  |  91   | 23
#      baseball-glove |  15  |  106  | 27
#     basketball-hoop |  9   |  65   | 16
#                 bat |  11  |  76   | 19
#             bathtub |  23  |  167  | 42
#                bear |  10  |  74   | 18
#            beer-mug |  9   |  68   | 17
#           billiards |  28  |  200  | 50
#          binoculars |  22  |  155  | 39
#            birdbath |  10  |  70   | 18
#               blimp |  9   |  62   | 15
#          bonsai-101 |  12  |  88   | 22
#            boom-box |  9   |  66   | 16
#        bowling-ball |  10  |  75   | 19
#         bowling-pin |  10  |  73   | 18
#        boxing-glove |  12  |  90   | 22
#           brain-101 |  8   |  60   | 15
#          breadmaker |  14  |  102  | 26
#          buddha-101 |  10  |  70   | 17
#           bulldozer |  11  |  79   | 20
#           butterfly |  11  |  81   | 20
#              cactus |  11  |  82   | 21
#                cake |  11  |  76   | 19
#          calculator |  10  |  72   | 18
#               camel |  11  |  79   | 20
#              cannon |  10  |  74   | 19
#               canoe |  10  |  75   | 19
#            car-tire |  9   |  65   | 16
#             cartman |  10  |  73   | 18
#                  cd |  10  |  74   | 18
#           centipede |  10  |  72   | 18
#          cereal-box |  9   |  62   | 16
#      chandelier-101 |  11  |  76   | 19
#         chess-board |  12  |  86   | 22
#               chimp |  11  |  79   | 20
#          chopsticks |  8   |  62   | 15
#           cockroach |  12  |  90   | 22
#          coffee-mug |  9   |  62   | 16
#              coffin |  9   |  62   | 16
#                coin |  12  |  90   | 22
#               comet |  12  |  87   | 22
#   computer-keyboard |  9   |  61   | 15
#    computer-monitor |  13  |  96   | 24
#      computer-mouse |  9   |  68   | 17
#               conch |  10  |  74   | 19
#           cormorant |  11  |  76   | 19
#       covered-wagon |  10  |  70   | 17
#          cowboy-hat |  11  |  82   | 21
#            crab-101 |  8   |  62   | 15
#          desk-globe |  8   |  59   | 15
#        diamond-ring |  12  |  85   | 21
#                dice |  10  |  70   | 18
#                 dog |  10  |  74   | 19
#         dolphin-101 |  11  |  76   | 19
#            doorknob |  9   |  67   | 17
#      drinking-straw |  8   |  60   | 15
#                duck |  9   |  62   | 16
#           dumb-bell |  10  |  74   | 18
#        eiffel-tower |  8   |  60   | 15
# electric-guitar-101 |  12  |  88   | 22
#        elephant-101 |  13  |  94   | 24
#                 elk |  10  |  73   | 18
#            ewer-101 |  8   |  60   | 15
#          eyeglasses |  8   |  60   | 15
#                fern |  11  |  79   | 20
#         fighter-jet |  10  |  71   | 18
#   fire-extinguisher |  8   |  61   | 15
#        fire-hydrant |  10  |  71   | 18
#          fire-truck |  12  |  85   | 21
#           fireworks |  10  |  72   | 18
#          flashlight |  12  |  82   | 21
#         floppy-disk |  8   |  60   | 15
#     football-helmet |  8   |  61   | 15
#         french-horn |  9   |  66   | 17
#           fried-egg |  9   |  65   | 16
#             frisbee |  10  |  71   | 18
#                frog |  12  |  83   | 21
#          frying-pan |  10  |  68   | 17
#              galaxy |  8   |  58   | 15
#            gas-pump |  10  |  68   | 17
#             giraffe |  8   |  61   | 15
#                goat |  11  |  81   | 20
#  golden-gate-bridge |  8   |  58   | 14
#            goldfish |  9   |  67   | 17
#           golf-ball |  10  |  70   | 18
#               goose |  11  |  79   | 20
#             gorilla |  21  |  153  | 38
#     grand-piano-101 |  10  |  68   | 17
#              grapes |  20  |  145  | 36
#         grasshopper |  11  |  81   | 20
#         guitar-pick |  10  |  75   | 19
#           hamburger |  9   |  62   | 15
#             hammock |  29  |  205  | 51
#           harmonica |  9   |  64   | 16
#                harp |  10  |  72   | 18
#         harpsichord |  8   |  58   | 14
#       hawksbill-101 |  9   |  67   | 17
#         head-phones |  14  |  99   | 25
#      helicopter-101 |  9   |  63   | 16
#            hibiscus |  11  |  80   | 20
#       homer-simpson |  10  |  70   | 17
#               horse |  27  |  194  | 49
#      horseshoe-crab |  9   |  62   | 16
#     hot-air-balloon |  9   |  64   | 16
#             hot-dog |  8   |  62   | 15
#             hot-tub |  16  |  112  | 28
#           hourglass |  9   |  61   | 15
#           house-fly |  8   |  61   | 15
#      human-skeleton |  8   |  61   | 15
#         hummingbird |  12  |  83   | 21
#            ibis-101 |  12  |  86   | 22
#      ice-cream-cone |  9   |  63   | 16
#              iguana |  11  |  77   | 19
#                ipod |  12  |  87   | 22
#                iris |  11  |  78   | 19
#        jesus-christ |  9   |  62   | 16
#           joy-stick |  13  |  94   | 23
#        kangaroo-101 |  8   |  59   | 15
#               kayak |  10  |  74   | 19
#           ketch-101 |  11  |  80   | 20
#        killer-whale |  9   |  66   | 16
#               knife |  10  |  73   | 18
#              ladder |  24  |  174  | 44
#          laptop-101 |  13  |  92   | 23
#               lathe |  11  |  75   | 19
#        leopards-101 |  19  |  137  | 34
#       license-plate |  9   |  66   | 16
#           lightbulb |  9   |  66   | 17
#         light-house |  19  |  137  | 34
#           lightning |  14  |  98   | 24
#           llama-101 |  12  |  86   | 21
#             mailbox |  9   |  67   | 17
#            mandolin |  9   |  67   | 17
#                mars |  16  |  112  | 28
#            mattress |  19  |  138  | 35
#           megaphone |  9   |  62   | 15
#         menorah-101 |  9   |  64   | 16
#          microscope |  12  |  84   | 21
#           microwave |  11  |  77   | 19
#             minaret |  13  |  94   | 23
#            minotaur |  8   |  59   | 15
#      motorbikes-101 |  80  |  574  | 144
#       mountain-bike |  8   |  59   | 15
#            mushroom |  20  |  146  | 36
#             mussels |  17  |  126  | 31
#             necktie |  10  |  74   | 19
#             octopus |  11  |  80   | 20
#             ostrich |  11  |  78   | 20
#                 owl |  12  |  86   | 22
#          palm-pilot |  9   |  67   | 17
#           palm-tree |  10  |  74   | 19
#           paperclip |  9   |  66   | 17
#      paper-shredder |  10  |  69   | 17
#            pci-card |  11  |  75   | 19
#             penguin |  15  |  107  | 27
#              people |  21  |  150  | 38
#       pez-dispenser |  8   |  60   | 15
#         photocopier |  10  |  74   | 19
#        picnic-table |  9   |  66   | 16
#        playing-card |  9   |  65   | 16
#           porcupine |  10  |  73   | 18
#                pram |  9   |  63   | 16
#      praying-mantis |  9   |  66   | 17
#             pyramid |  9   |  62   | 15
#             raccoon |  14  |  101  | 25
#     radio-telescope |  9   |  66   | 17
#             rainbow |  10  |  74   | 18
#        refrigerator |  8   |  61   | 15
#        revolver-101 |  10  |  71   | 18
#               rifle |  11  |  76   | 19
#        rotary-phone |  8   |  61   | 15
#      roulette-wheel |  8   |  60   | 15
#              saddle |  11  |  79   | 20
#              saturn |  10  |  69   | 17
#          school-bus |  10  |  70   | 18
#        scorpion-101 |  8   |  58   | 14
#         screwdriver |  10  |  74   | 18
#              segway |  10  |  72   | 18
# self-propelled-lawn-mower |  12  |  86   | 22
#             sextant |  10  |  72   | 18
#         sheet-music |  8   |  61   | 15
#          skateboard |  10  |  74   | 19
#               skunk |  8   |  58   | 15
#          skyscraper |  10  |  68   | 17
#          smokestack |  9   |  63   | 16
#               snail |  12  |  86   | 21
#               snake |  11  |  81   | 20
#             sneaker |  11  |  80   | 20
#          snowmobile |  11  |  81   | 20
#         soccer-ball |  17  |  126  | 31
#               socks |  11  |  81   | 20
#            soda-can |  9   |  62   | 16
#           spaghetti |  10  |  75   | 19
#          speed-boat |  10  |  72   | 18
#              spider |  11  |  78   | 20
#               spoon |  11  |  75   | 19
#       stained-glass |  10  |  72   | 18
#        starfish-101 |  8   |  59   | 14
#      steering-wheel |  10  |  70   | 17
#            stirrups |  9   |  66   | 16
#       sunflower-101 |  8   |  58   | 14
#            superman |  9   |  62   | 16
#               sushi |  10  |  70   | 18
#                swan |  12  |  82   | 21
#    swiss-army-knife |  11  |  78   | 20
#               sword |  10  |  74   | 18
#             syringe |  11  |  80   | 20
#          tambourine |  10  |  68   | 17
#              teapot |  14  |  98   | 24
#          teddy-bear |  10  |  73   | 18
#              teepee |  14  |  100  | 25
#       telephone-box |  8   |  61   | 15
#         tennis-ball |  10  |  70   | 18
#        tennis-court |  11  |  75   | 19
#       tennis-racket |  8   |  58   | 15
#          theodolite |  8   |  61   | 15
#             toaster |  9   |  68   | 17
#              tomato |  10  |  74   | 19
#           tombstone |  9   |  66   | 16
#             top-hat |  8   |  58   | 14
#        touring-bike |  11  |  79   | 20
#          tower-pisa |  9   |  65   | 16
#       traffic-light |  10  |  71   | 18
#           treadmill |  15  |  106  | 26
#         triceratops |  10  |  68   | 17
#            tricycle |  10  |  68   | 17
#       trilobite-101 |  9   |  68   | 17
#              tripod |  11  |  81   | 20
#             t-shirt |  36  |  258  | 64
#         tuning-fork |  10  |  72   | 18
#             tweezer |  12  |  88   | 22
#        umbrella-101 |  11  |  82   | 21
#             unicorn |  10  |  70   | 17
#                 vcr |  9   |  65   | 16
#     video-projector |  10  |  70   | 17
#     washing-machine |  8   |  61   | 15
#           watch-101 |  20  |  145  | 36
#           waterfall |  10  |  68   | 17
#          watermelon |  9   |  67   | 17
#        welding-mask |  9   |  65   | 16
#         wheelbarrow |  9   |  66   | 16
#            windmill |  9   |  66   | 16
#         wine-bottle |  10  |  73   | 18
#           xylophone |  9   |  66   | 17
#            yarmulke |  8   |  61   | 15
#               yo-yo |  10  |  72   | 18
#               zebra |  10  |  69   | 17
#       airplanes-101 |  80  |  576  | 144
#        car-side-101 |  12  |  83   | 21
#      faces-easy-101 |  44  |  313  | 78
#           greyhound |  10  |  68   | 17
#        tennis-shoes |  10  |  74   | 19
#                toad |  11  |  78   | 19
#             clutter |  83  |  595  | 149

# %%
BATCH_SIZE = 6
TARGET_SIZE = (224, 224)

def load_data(df, b_size=BATCH_SIZE, shuffle=True, class_weights=None):
    """Loads the data using an ImageDataGenerator."""
    generator = ImageDataGenerator(rescale=1 / 255.)

    df["file_paths"] = df["file_paths"].astype(str)
    
    if class_weights:
        class_weights = {key: class_weights[key] for key in sorted(class_weights.keys())}
        class_weights

    data = generator.flow_from_dataframe(
        df,
        x_col="file_paths",
        y_col="labels",
        target_size=TARGET_SIZE,
        class_mode="categorical",
        shuffle=shuffle,
        batch_size=b_size,
        class_weight=class_weights,
        random_state=RANDOM_STATE
    )

    invalid_filenames = df.loc[~df['file_paths'].isin(data.filenames), 'file_paths']
    if not invalid_filenames.empty:
        print("Invalid filenames:", invalid_filenames.tolist())

    return data

train_data = load_data(train_df)
valid_data = load_data(valid_df, shuffle=False)
test_data = load_data(test_df, shuffle=False)
# Out:
# Found 22036 validated image filenames belonging to 257 classes.
# Invalid filenames: ['/kaggle/working/data/256_ObjectCategories/056.dog/greg', '/kaggle/working/data/256_ObjectCategories/198.spider/RENAME2']
# Found 5510 validated image filenames belonging to 257 classes.
# Found 3061 validated image filenames belonging to 257 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 2 invalid image filename(s) in x_col="file_paths". These filename(s) will be ignored.
#   warnings.warn(

# %%
def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """Calculates the F1 score."""
        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """Calculates the specificity."""
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """Calculates the sensitivity."""
        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).
        
        This approach allows for a nuanced assessment of the model's ability to distinguish
        between different classes, making it particularly valuable in scenarios where classes
        may have varying levels of significance.
        
        """
        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """Calculates the number of true positives."""
        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """Calculates the number of false positives."""
        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """Calculates the number of false negatives."""
        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """Calculates the number of true negatives."""
        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """Calculates the components of the confusion matrix."""
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

custom_metrics = create_metrics()

# precision_metric, recall_metric, f1_score_metric, specificity_metric, sensitivity_metric, mcc_metric, auc_metric = custom_metrics

# %%
# Load the pre-trained Xception model
base_model = Xception(weights='imagenet', include_top=True, input_shape=(299, 299, 3))

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 1s 0us/step
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 74, 74, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 37, 37, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 19, 19, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22910480 (87.40 MB)
# Trainable params: 22855952 (87.19 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
# Load the pre-trained Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

# Create a custom model by adding new dense layers on top of the pre-trained model
x = GlobalAveragePooling2D()(base_model.output)
# removed dense layers
output = Dense(257, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_2[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 74, 74, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 37, 37, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 19, 19, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 19, 19, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 257)                  526593    ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 21388073 (81.59 MB)
# Trainable params: 21333545 (81.38 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=1e-4),
    metrics=["accuracy", create_metrics()]
)

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs: Optional[Dict] = None) -> None:
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch: int, logs: Optional[Dict] = None) -> None:
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch: int, logs: Optional[Dict] = None) -> None:
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs: Optional[Dict] = None) -> None:
        """Calculate total training time."""
        if logs is not None:
            self.total_train_time = time.perf_counter() - self.train_start_time
            logs['total_train_time'] = self.total_train_time
            print(f"Total training time: {self.total_train_time} seconds")

# Create an instance of the TimeCallback
time_callback = TimeCallback()

# %%
total_epochs = 50

history = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=total_epochs,
    callbacks=[time_callback, early_stopping]
)
# Out:
# Epoch 1/50
# 3673/3673 [==============================] - 310s 75ms/step - loss: 1.9239 - accuracy: 0.6183 - precision_1: 0.9277 - recall_1: 0.4201 - f1_score: 0.5250 - specificity: 0.9999 - sensitivity: 0.4201 - mcc: 0.5633 - auc_1: 0.9483 - val_loss: 0.8463 - val_accuracy: 0.7964 - val_precision_1: 0.8735 - val_recall_1: 0.7446 - val_f1_score: 0.7992 - val_specificity: 0.9996 - val_sensitivity: 0.7448 - val_mcc: 0.8040 - val_auc_1: 0.9790
# Epoch 2/50
# 3673/3673 [==============================] - 273s 74ms/step - loss: 0.5149 - accuracy: 0.8748 - precision_1: 0.9445 - recall_1: 0.8088 - f1_score: 0.8647 - specificity: 0.9998 - sensitivity: 0.8088 - mcc: 0.8703 - auc_1: 0.9941 - val_loss: 0.8089 - val_accuracy: 0.8169 - val_precision_1: 0.8727 - val_recall_1: 0.7902 - val_f1_score: 0.8259 - val_specificity: 0.9995 - val_sensitivity: 0.7900 - val_mcc: 0.8282 - val_auc_1: 0.9757
# Epoch 3/50
# 3673/3673 [==============================] - 273s 74ms/step - loss: 0.2541 - accuracy: 0.9357 - precision_1: 0.9658 - recall_1: 0.9061 - f1_score: 0.9320 - specificity: 0.9999 - sensitivity: 0.9061 - mcc: 0.9337 - auc_1: 0.9980 - val_loss: 0.8935 - val_accuracy: 0.8167 - val_precision_1: 0.8657 - val_recall_1: 0.7969 - val_f1_score: 0.8274 - val_specificity: 0.9995 - val_sensitivity: 0.7971 - val_mcc: 0.8292 - val_auc_1: 0.9701
# Epoch 4/50
# 3673/3673 [==============================] - 273s 74ms/step - loss: 0.1644 - accuracy: 0.9572 - precision_1: 0.9721 - recall_1: 0.9392 - f1_score: 0.9538 - specificity: 0.9999 - sensitivity: 0.9392 - mcc: 0.9545 - auc_1: 0.9989 - val_loss: 1.0259 - val_accuracy: 0.8011 - val_precision_1: 0.8407 - val_recall_1: 0.7846 - val_f1_score: 0.8087 - val_specificity: 0.9994 - val_sensitivity: 0.7844 - val_mcc: 0.8097 - val_auc_1: 0.9622
# Epoch 5/50
# 3673/3673 [==============================] - 270s 74ms/step - loss: 0.1320 - accuracy: 0.9645 - precision_1: 0.9779 - recall_1: 0.9517 - f1_score: 0.9634 - specificity: 0.9999 - sensitivity: 0.9516 - mcc: 0.9640 - auc_1: 0.9989 - val_loss: 1.0252 - val_accuracy: 0.8069 - val_precision_1: 0.8438 - val_recall_1: 0.7924 - val_f1_score: 0.8147 - val_specificity: 0.9994 - val_sensitivity: 0.7922 - val_mcc: 0.8156 - val_auc_1: 0.9624
# Epoch 6/50
# 3673/3673 [==============================] - 270s 73ms/step - loss: 0.1199 - accuracy: 0.9680 - precision_1: 0.9778 - recall_1: 0.9581 - f1_score: 0.9668 - specificity: 0.9999 - sensitivity: 0.9581 - mcc: 0.9673 - auc_1: 0.9989 - val_loss: 1.0933 - val_accuracy: 0.8114 - val_precision_1: 0.8455 - val_recall_1: 0.7953 - val_f1_score: 0.8178 - val_specificity: 0.9994 - val_sensitivity: 0.7954 - val_mcc: 0.8187 - val_auc_1: 0.9585
# Epoch 7/50
# 3673/3673 [==============================] - 270s 73ms/step - loss: 0.1063 - accuracy: 0.9707 - precision_1: 0.9797 - recall_1: 0.9621 - f1_score: 0.9699 - specificity: 0.9999 - sensitivity: 0.9620 - mcc: 0.9702 - auc_1: 0.9990 - val_loss: 1.1122 - val_accuracy: 0.8049 - val_precision_1: 0.8383 - val_recall_1: 0.7933 - val_f1_score: 0.8134 - val_specificity: 0.9994 - val_sensitivity: 0.7934 - val_mcc: 0.8142 - val_auc_1: 0.9566
# Epoch 8/50
# 3673/3673 [==============================] - 270s 74ms/step - loss: 0.1035 - accuracy: 0.9720 - precision_1: 0.9801 - recall_1: 0.9628 - f1_score: 0.9706 - specificity: 0.9999 - sensitivity: 0.9628 - mcc: 0.9709 - auc_1: 0.9989 - val_loss: 1.2107 - val_accuracy: 0.8058 - val_precision_1: 0.8357 - val_recall_1: 0.7967 - val_f1_score: 0.8144 - val_specificity: 0.9994 - val_sensitivity: 0.7969 - val_mcc: 0.8148 - val_auc_1: 0.9520
# Epoch 9/50
# 3673/3673 [==============================] - 270s 74ms/step - loss: 0.0936 - accuracy: 0.9749 - precision_1: 0.9821 - recall_1: 0.9687 - f1_score: 0.9747 - specificity: 0.9999 - sensitivity: 0.9687 - mcc: 0.9750 - auc_1: 0.9989 - val_loss: 1.2125 - val_accuracy: 0.8025 - val_precision_1: 0.8328 - val_recall_1: 0.7917 - val_f1_score: 0.8099 - val_specificity: 0.9994 - val_sensitivity: 0.7914 - val_mcc: 0.8103 - val_auc_1: 0.9527
# Epoch 10/50
# 3673/3673 [==============================] - 269s 73ms/step - loss: 0.0860 - accuracy: 0.9761 - precision_1: 0.9827 - recall_1: 0.9696 - f1_score: 0.9755 - specificity: 0.9999 - sensitivity: 0.9696 - mcc: 0.9758 - auc_1: 0.9991 - val_loss: 1.1974 - val_accuracy: 0.7949 - val_precision_1: 0.8357 - val_recall_1: 0.7829 - val_f1_score: 0.8065 - val_specificity: 0.9994 - val_sensitivity: 0.7831 - val_mcc: 0.8074 - val_auc_1: 0.9537
# Epoch 11/50
# 3673/3673 [==============================] - 270s 73ms/step - loss: 0.0894 - accuracy: 0.9763 - precision_1: 0.9835 - recall_1: 0.9701 - f1_score: 0.9762 - specificity: 0.9999 - sensitivity: 0.9701 - mcc: 0.9764 - auc_1: 0.9989 - val_loss: 1.2777 - val_accuracy: 0.7946 - val_precision_1: 0.8287 - val_recall_1: 0.7842 - val_f1_score: 0.8037 - val_specificity: 0.9994 - val_sensitivity: 0.7844 - val_mcc: 0.8043 - val_auc_1: 0.9517
# Epoch 12/50
# 3673/3673 [==============================] - 270s 73ms/step - loss: 0.0781 - accuracy: 0.9784 - precision_1: 0.9840 - recall_1: 0.9741 - f1_score: 0.9786 - specificity: 0.9999 - sensitivity: 0.9741 - mcc: 0.9788 - auc_1: 0.9990 - val_loss: 1.3787 - val_accuracy: 0.7880 - val_precision_1: 0.8225 - val_recall_1: 0.7788 - val_f1_score: 0.7985 - val_specificity: 0.9993 - val_sensitivity: 0.7789 - val_mcc: 0.7991 - val_auc_1: 0.9479
# Total training time: 3287.522529492 seconds

# %%
# Calculate and print time
total_train_time = time_callback.total_train_time
epoch_times = time_callback.epoch_times.copy()

execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(total_train_time // unit[0])
    avg_value = int(np.mean(epoch_times) // unit[0]) if unit[0] != 0 else 0

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    total_train_time -= total_value * unit[0]
    epoch_times = [time - avg_value * unit[0] for time in epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 54 minutes, 47 seconds, 522 milliseconds
# Average time per epoch: 04 minutes, 33 seconds, 895 milliseconds

# %%
# Test the model against testing data
_ = model.evaluate(test_data)
# Out:
# 511/511 [==============================] - 11s 22ms/step - loss: 0.7688 - accuracy: 0.8255 - precision_1: 0.8677 - recall_1: 0.7948 - f1_score: 0.8260 - specificity: 0.9995 - sensitivity: 0.7952 - mcc: 0.8279 - auc_1: 0.9780

# %%
def plot_metrics(history, metric_name_list, figure_size=(10, 6)):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        history: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot
        figure_size: a tuple specifying the size of the figure (width, height)

    Returns:
        None
    """
    # Check if history is a valid Keras History object
    if not isinstance(history, type(tf.keras.callbacks.History())):
        raise ValueError("Invalid Keras History object provided.")

    num_metrics = len(metric_name_list)

    # Create subplots
    figure, axes = plt.subplots(num_metrics, figsize=(figure_size[0], figure_size[1] * num_metrics))

    # Define x-axis range
    rng = range(1, len(history.history[metric_name_list[0]]) + 1)

    for ax, metric_name in zip(axes, metric_name_list):
        # Check if the metric exists in the history
        if metric_name not in history.history:
            raise ValueError(f"Metric '{metric_name}' not found in the training history.")

        metric = history.history[metric_name]
        v_metric = history.history.get(f"val_{metric_name}", None)

        # Plot training metric
        ax.plot(rng, metric, label=metric_name)

        # Plot validation metric if available
        if v_metric is not None:
            ax.plot(rng, v_metric, label=f"val_{metric_name}")

        ax.legend()
        ax.set_xlabel("Epochs")

        # Set y-axis label and title
        ylabel = metric_name.upper() if metric_name in ("auc", "mcc") else metric_name.capitalize()
        ax.set_ylabel(ylabel)
        ax.set_title(f"{ylabel} vs Epochs")

        # Set y-axis limits
        max_loss = max(max(metric), max(v_metric)) if v_metric is not None else max(metric)
        min_loss = min(min(metric), min(v_metric)) if v_metric is not None else min(metric)
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()
    plt.show()

metric_names = ["loss", "accuracy", "precision_1", "recall_1", "f1_score",
                "specificity", "sensitivity", "mcc", "auc_1"]
plot_metrics(history, metric_names)

# %%
# Assuming you have a DataFrame 'df' with a 'labels' column
classes = df['labels'].unique()

# Convert predicted probabilities to class labels
predictions = model.predict(test_data)
predicted_labels = predictions.argmax(axis=1)

true_labels = test_data.classes
tests = len(true_labels)

# Calculate accuracy score
accuracy = accuracy_score(true_labels, predicted_labels)
accuracy_percentage = accuracy * 100

# Calculate the total number of errors
errors = np.sum(predicted_labels != true_labels)

# Print the classification report with class names and values in decimals
report = classification_report(true_labels, predicted_labels, target_names=classes, digits=4)

print(report)
print(f'There were {errors} errors in {tests} tests for an accuracy of {accuracy_percentage:6.2f}%')
# Out:
# 511/511 [==============================] - 10s 18ms/step
#                            precision    recall  f1-score   support
#
#                      ak47     0.9405    0.9875    0.9634        80
#             american-flag     0.8889    0.8000    0.8421        10
#                  backpack     0.7500    0.9000    0.8182        10
#              baseball-bat     1.0000    0.9333    0.9655        15
#            baseball-glove     0.7500    0.6923    0.7200        13
#           basketball-hoop     1.0000    0.8667    0.9286        15
#                       bat     0.8889    0.8889    0.8889         9
#                   bathtub     1.0000    0.4545    0.6250        11
#                      bear     0.9048    0.8261    0.8636        23
#                  beer-mug     0.8000    0.8000    0.8000        10
#                 billiards     0.8750    0.7778    0.8235         9
#                binoculars     0.9310    0.9643    0.9474        28
#                  birdbath     0.9130    0.9545    0.9333        22
#                     blimp     0.9000    0.9000    0.9000        10
#                bonsai-101     1.0000    0.8889    0.9412         9
#                  boom-box     0.8571    1.0000    0.9231        12
#              bowling-ball     1.0000    0.8889    0.9412         9
#               bowling-pin     0.5385    0.7000    0.6087        10
#              boxing-glove     0.7500    0.6000    0.6667        10
#            steering-wheel     0.7692    1.0000    0.8696        10
#                  stirrups     1.0000    0.4545    0.6250        11
#             sunflower-101     0.5625    0.8182    0.6667        11
#                  superman     0.8889    0.8000    0.8421        10
#                     sushi     0.7273    1.0000    0.8421         8
#                      swan     0.8889    0.8000    0.8421        10
#          swiss-army-knife     0.6667    0.6667    0.6667         9
#                     sword     1.0000    1.0000    1.0000         8
#                   syringe     0.7500    0.3333    0.4615         9
#                tambourine     0.5833    0.7000    0.6364        10
#                    teapot     0.6923    0.7500    0.7200        12
#                teddy-bear     0.7692    0.9091    0.8333        11
#                    teepee     0.8000    0.8000    0.8000        10
#             telephone-box     0.6667    0.5455    0.6000        11
#               tennis-ball     0.9714    0.9444    0.9577        36
#              tennis-court     1.0000    0.5000    0.6667        10
#             tennis-racket     0.8667    0.9286    0.8966        14
#                theodolite     0.9091    1.0000    0.9524        10
#                   toaster     0.9333    1.0000    0.9655        14
#                    tomato     1.0000    0.8750    0.9333         8
#                 tombstone     1.0000    0.6000    0.7500        10
#                   top-hat     0.7857    1.0000    0.8800        11
#              touring-bike     1.0000    0.8750    0.9333         8
#                tower-pisa     0.8571    0.6000    0.7059        10
#             traffic-light     0.7500    0.7500    0.7500         8
#                 treadmill     0.6471    1.0000    0.7857        11
#               triceratops     0.8000    0.8889    0.8421         9
#                  tricycle     1.0000    0.9000    0.9474        10
#             trilobite-101     0.7778    0.7778    0.7778         9
#                    tripod     1.0000    0.5000    0.6667         8
#                   t-shirt     0.6111    1.0000    0.7586        11
#               tuning-fork     1.0000    0.6667    0.8000         9
#                   tweezer     0.7500    0.6000    0.6667        10
#              umbrella-101     0.6667    0.9333    0.7778        15
#                   unicorn     1.0000    0.9000    0.9474        10
#                       vcr     1.0000    0.7000    0.8235        10
#           video-projector     1.0000    0.8889    0.9412         9
#           washing-machine     0.8462    1.0000    0.9167        11
#                 watch-101     0.8000    0.8000    0.8000        10
#                 waterfall     0.7143    0.8333    0.7692        12
#                watermelon     0.7143    0.9091    0.8000        11
#              welding-mask     0.8182    0.9000    0.8571        10
#               wheelbarrow     0.8889    0.8889    0.8889         9
#                  windmill     1.0000    0.9000    0.9474        10
#               wine-bottle     1.0000    0.8750    0.9333         8
#                 xylophone     0.9524    1.0000    0.9756        20
#                  yarmulke     1.0000    0.9000    0.9474        10
#                     yo-yo     0.8571    0.6667    0.7500         9
#                     zebra     0.6000    1.0000    0.7500         9
#             airplanes-101     0.7000    0.7778    0.7368         9
#              car-side-101     0.8333    0.5556    0.6667         9
#            faces-easy-101     0.8000    0.8000    0.8000        10
#                 greyhound     0.7500    0.6667    0.7059         9
#              tennis-shoes     0.7778    0.8750    0.8235         8
#                      toad     0.3333    0.1000    0.1538        10
#                   clutter     1.0000    1.0000    1.0000        10
#
#                  accuracy                         0.8255      3061
#                 macro avg     0.8337    0.8027    0.8050      3061
#              weighted avg     0.8422    0.8255    0.8226      3061
#
# There were 534 errors in 3061 tests for an accuracy of  82.55%
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
