# %%
import os
import time
import math
import subprocess

from tqdm import tqdm
from glob import glob
from pathlib import Path
from tabulate import tabulate
from typing import Optional, Dict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Downloading and Extracting Caltech-101 Dataset in Kaggle
# !wget https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# !unzip /kaggle/working/caltech-101.zip
# !mkdir data
# !tar -xf /kaggle/working/caltech-101/101_ObjectCategories.tar.gz -C /kaggle/working/data
# Out:
# --2023-12-07 17:38:55--  https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# Resolving data.caltech.edu (data.caltech.edu)... 35.155.11.48
# Connecting to data.caltech.edu (data.caltech.edu)|35.155.11.48|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://s3.us-west-2.amazonaws.com/caltechdata/47/20/fc77-d78a-4c50-81c9-d47c2004df45/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dcaltech-101.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231207%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231207T173855Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=e9e46764d86ae7f141aebc6f80b0e71f776c3324420962e2a97caf975a5a4a24 [following]
# --2023-12-07 17:38:55--  https://s3.us-west-2.amazonaws.com/caltechdata/47/20/fc77-d78a-4c50-81c9-d47c2004df45/data?response-content-type=application%2Foctet-stream&response-content-disposition=attachment%3B%20filename%3Dcaltech-101.zip&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIARCVIVNNAP7NNDVEA%2F20231207%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231207T173855Z&X-Amz-Expires=60&X-Amz-SignedHeaders=host&X-Amz-Signature=e9e46764d86ae7f141aebc6f80b0e71f776c3324420962e2a97caf975a5a4a24
# Resolving s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)... 52.218.153.160, 52.92.177.160, 52.92.165.104, ...
# Connecting to s3.us-west-2.amazonaws.com (s3.us-west-2.amazonaws.com)|52.218.153.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137414764 (131M) [application/octet-stream]
# Saving to: ‘caltech-101.zip’
#
# caltech-101.zip     100%[===================>] 131.05M  17.8MB/s    in 7.7s
#
# 2023-12-07 17:39:04 (17.1 MB/s) - ‘caltech-101.zip’ saved [137414764/137414764]
#
# Archive:  /kaggle/working/caltech-101.zip
#    creating: caltech-101/
#   inflating: __MACOSX/._caltech-101
#   inflating: caltech-101/101_ObjectCategories.tar.gz
#   inflating: __MACOSX/caltech-101/._101_ObjectCategories.tar.gz
#   inflating: caltech-101/show_annotation.m
#   inflating: __MACOSX/caltech-101/._show_annotation.m
#   inflating: caltech-101/Annotations.tar
#   inflating: __MACOSX/caltech-101/._Annotations.tar

# %%
# # Downloading and Extracting Caltech-101 Dataset in Colab
# !wget https://data.caltech.edu/records/mzrjq-6wc02/files/caltech-101.zip
# !unzip /content/caltech-101.zip
# !mkdir data
# !tar -xf /content/caltech-101/101_ObjectCategories.tar.gz -C /content/data
# !rm /content/caltech-101.zip
# !rm -r /content/sample_data /content/caltech-101

# %%
data_path = Path(r"/kaggle/working/data/101_ObjectCategories") # for kaggle
# data_path = Path(r"/content/data/101_ObjectCategories") # for colab

# %%
def count_images_per_class(path):
    """
    Prints the number of images in each class in the dataset.

    Parameters:
    -----------
    path: Path
        The path to the dataset.

    Returns:
    --------
    None. Prints the number of images in each class to the console.
    """
    table = [["No.", "Classes", "Images"]]

    index = 1
    for folder in sorted(path.iterdir(), key=lambda f: sum(1 for _ in f.glob("*") if _.is_file())):
        if folder.is_dir():
            sample_size = sum(1 for _ in folder.glob("*") if _.is_file())
            table.append([index, folder.stem, sample_size])
            index += 1

    # Print the table of images per class
    print(tabulate(table, headers="firstrow", tablefmt="pretty"))

# Count images per class in the dataset
count_images_per_class(data_path)
# Out:
# +-----+-------------------+--------+
# | No. |      Classes      | Images |
# +-----+-------------------+--------+
# |  1  |   inline_skate    |   31   |
# |  2  |     metronome     |   32   |
# |  3  |     binocular     |   33   |
# |  4  |      gerenuk      |   34   |
# |  5  |     garfield      |   34   |
# |  6  |     platypus      |   34   |
# |  7  |     wild_cat      |   34   |
# |  8  |      snoopy       |   35   |
# |  9  |      octopus      |   35   |
# | 10  |    strawberry     |   35   |
# | 11  |    water_lilly    |   37   |
# | 12  |       panda       |   38   |
# | 13  |     scissors      |   39   |
# | 14  |      wrench       |   39   |
# | 15  |       okapi       |   39   |
# | 16  |     saxophone     |   40   |
# | 17  |      mayfly       |   40   |
# | 18  |      lobster      |   41   |
# | 19  |        ant        |   42   |
# | 20  |     headphone     |   42   |
# | 21  |      anchor       |   42   |
# | 22  |     mandolin      |   43   |
# | 23  |      cannon       |   43   |
# | 24  |   brontosaurus    |   43   |
# | 25  |      stapler      |   45   |
# | 26  |      pigeon       |   45   |
# | 27  |   flamingo_head   |   45   |
# | 28  |      beaver       |   46   |
# | 29  |      barrel       |   47   |
# | 30  |    ceiling_fan    |   47   |
# | 31  |      pagoda       |   47   |
# | 32  |    cougar_body    |   47   |
# | 33  |       tick        |   49   |
# | 34  |      rooster      |   49   |
# | 35  |      camera       |   50   |
# | 36  |     crocodile     |   50   |
# | 37  |    gramophone     |   51   |
# | 38  |  crocodile_head   |   51   |
# | 39  |    dollar_bill    |   52   |
# | 40  |        emu        |   53   |
# | 41  |       pizza       |   53   |
# | 42  |     hedgehog      |   54   |
# | 43  |       bass        |   54   |
# | 44  |     accordion     |   55   |
# | 45  |     nautilus      |   55   |
# | 46  |   windsor_chair   |   56   |
# | 47  |      pyramid      |   57   |
# | 48  |        cup        |   57   |
# | 49  |     sea_horse     |   57   |
# | 50  |    stegosaurus    |   59   |
# | 51  |       rhino       |   59   |
# | 52  |    wheelchair     |   59   |
# | 53  |     cellphone     |   59   |
# | 54  |     yin_yang      |   60   |
# | 55  |       lamp        |   61   |
# | 56  |       chair       |   62   |
# | 57  |     schooner      |   63   |
# | 58  |     elephant      |   64   |
# | 59  |    joshua_tree    |   64   |
# | 60  |     euphonium     |   64   |
# | 61  |     stop_sign     |   64   |
# | 62  |    soccer_ball    |   64   |
# | 63  |      dolphin      |   65   |
# | 64  |       lotus       |   66   |
# | 65  |     flamingo      |   67   |
# | 66  |     dalmatian     |   67   |
# | 67  |       ferry       |   67   |
# | 68  |     dragonfly     |   68   |
# | 69  |    cougar_face    |   69   |
# | 70  |     crayfish      |   70   |
# | 71  |       crab        |   73   |
# | 72  |     umbrella      |   75   |
# | 73  |  electric_guitar  |   75   |
# | 74  |      minaret      |   76   |
# | 75  |       llama       |   78   |
# | 76  |       ibis        |   80   |
# | 77  |      laptop       |   81   |
# | 78  |     revolver      |   82   |
# | 79  |     scorpion      |   84   |
# | 80  |       ewer        |   85   |
# | 81  |      buddha       |   85   |
# | 82  |     sunflower     |   85   |
# | 83  |     kangaroo      |   86   |
# | 84  |     starfish      |   86   |
# | 85  |     trilobite     |   86   |
# | 86  |      menorah      |   87   |
# | 87  |    helicopter     |   88   |
# | 88  |     butterfly     |   91   |
# | 89  |       brain       |   98   |
# | 90  |    grand_piano    |   99   |
# | 91  |     hawksbill     |  100   |
# | 92  |    chandelier     |  107   |
# | 93  |       ketch       |  114   |
# | 94  |     car_side      |  123   |
# | 95  |      bonsai       |  128   |
# | 96  |     Leopards      |  200   |
# | 97  |       watch       |  239   |
# | 98  |    Faces_easy     |  435   |
# | 99  |       Faces       |  435   |
# | 100 | BACKGROUND_Google |  468   |
# | 101 |    Motorbikes     |  798   |
# | 102 |     airplanes     |  800   |
# +-----+-------------------+--------+

# %%
def prepare_data(path):
    """
    Prepares the training, validation, and test dataframes.

    Parameters:
    -----------
    path: str
        The path to the dataset.

    Returns:
    --------
    tuple
        A tuple containing the training, validation, and test dataframes.
    """
    path = Path(path)
    
    if not path.exists():
        raise FileNotFoundError(f"Directory not found: {path}")

    file_paths = []
    labels = []

    for class_dir in sorted(path.iterdir()):
        if class_dir.is_dir():
            class_files = list(class_dir.glob("*"))
            file_paths.extend(str(file) for file in class_files if file.is_file())
            labels.extend([class_dir.stem] * len(class_files))

    print(f"Files: {len(file_paths)}\n"
          f"Labels: {len(labels)}\n")

    df = pd.DataFrame({"file_paths": file_paths, "labels": labels})

    tr_df, te_df = train_test_split(df, test_size=0.3, stratify=df["labels"], random_state=81)
    tr_df, v_df = train_test_split(tr_df, test_size=0.2, stratify=tr_df["labels"], random_state=81)

    print(f"Training Data: {tr_df.shape[0]} samples\n"
          f"Testing Data: {te_df.shape[0]} samples\n"
          f"Validation Data: {v_df.shape[0]} samples")

    return tr_df, v_df, te_df, df

train_df, valid_df, test_df, df = prepare_data(data_path)
# Out:
# Files: 9145
# Labels: 9145
#
# Training Data: 5120 samples
# Testing Data: 2744 samples
# Validation Data: 1281 samples
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
# State the batch size
batch_size = 6

def load_data(df, b_size=batch_size, shuffle=True, random_state=81, workers=1):
    generator = ImageDataGenerator(
        rescale=1 / 255.,
        # Add more augmentation parameters if needed
    )

    data = generator.flow_from_dataframe(
        df,
        x_col="file_paths",
        y_col="labels",
        target_size=(224, 224),
        class_mode="categorical",
        shuffle=shuffle,
        batch_size=b_size,
        seed=random_state,
        workers=workers
    )

    # Print a warning for invalid filenames
    invalid_filenames = df.loc[~df['file_paths'].isin(data.filenames), 'file_paths']
    if not invalid_filenames.empty:
        print("Warning: Invalid filenames found and will be ignored:", invalid_filenames.tolist())

    return data

# Load the training, validation, and test data with consistent random_state
train_data = load_data(train_df)
valid_data = load_data(valid_df, shuffle=False)
test_data = load_data(test_df, shuffle=False)
# Out:
# Found 5119 validated image filenames belonging to 102 classes.
# Warning: Invalid filenames found and will be ignored: ['/kaggle/working/data/101_ObjectCategories/BACKGROUND_Google/tmp']
# Found 1281 validated image filenames belonging to 102 classes.
# Found 2744 validated image filenames belonging to 102 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="file_paths". These filename(s) will be ignored.
#   warnings.warn(

# %%
def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """Calculates the F1 score."""
        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """Calculates the specificity."""
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """Calculates the sensitivity."""
        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).
        
        This approach allows for a nuanced assessment of the model's ability to distinguish
        between different classes, making it particularly valuable in scenarios where classes
        may have varying levels of significance.
        
        """
        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """Calculates the number of true positives."""
        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """Calculates the number of false positives."""
        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """Calculates the number of false negatives."""
        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """Calculates the number of true negatives."""
        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """Calculates the components of the confusion matrix."""
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

custom_metrics = create_metrics()

# precision_metric, recall_metric, f1_score_metric, specificity_metric, sensitivity_metric, mcc_metric, auc_metric = custom_metrics

# %%
# Load the pre-trained Xception model
base_model = Xception(weights='imagenet', include_top=True, input_shape=(299, 299, 3))

base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 3s 0us/step
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 74, 74, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 37, 37, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 19, 19, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22910480 (87.40 MB)
# Trainable params: 22855952 (87.19 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
# Load the pre-trained Xception model
base_model = Xception(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

# Create a custom model by adding new dense layers on top of the pre-trained model
x = GlobalAveragePooling2D()(base_model.output)
# removed dense layers
output = Dense(102, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 3s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_2[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 74, 74, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 37, 37, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 19, 19, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 19, 19, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 102)                  208998    ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 21070478 (80.38 MB)
# Trainable params: 21015950 (80.17 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=Adam(learning_rate=1e-4),
    metrics=["accuracy", create_metrics()]
)

# %%
# Define the EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs: Optional[Dict] = None) -> None:
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch: int, logs: Optional[Dict] = None) -> None:
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch: int, logs: Optional[Dict] = None) -> None:
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs: Optional[Dict] = None) -> None:
        """Calculate total training time."""
        if logs is not None:
            self.total_train_time = time.perf_counter() - self.train_start_time
            logs['total_train_time'] = self.total_train_time
            print(f"Total training time: {self.total_train_time} seconds")

# Create an instance of the TimeCallback
time_callback = TimeCallback()

# %%
total_epochs = 50

history = model.fit(
    train_data,
    validation_data=valid_data,
    epochs=total_epochs,
    callbacks=[time_callback, early_stopping]
)
# Out:
# Epoch 1/50
# 854/854 [==============================] - 100s 77ms/step - loss: 1.4916 - accuracy: 0.7064 - precision_1: 0.9601 - recall_1: 0.5130 - f1_score: 0.6137 - specificity: 0.9998 - sensitivity: 0.5125 - mcc: 0.6472 - auc_1: 0.9723 - val_loss: 0.2806 - val_accuracy: 0.9251 - val_precision_1: 0.9523 - val_recall_1: 0.9040 - val_f1_score: 0.9256 - val_specificity: 0.9996 - val_sensitivity: 0.9042 - val_mcc: 0.9265 - val_auc_1: 0.9958
# Epoch 2/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.2201 - accuracy: 0.9562 - precision_1: 0.9757 - recall_1: 0.9195 - f1_score: 0.9427 - specificity: 0.9998 - sensitivity: 0.9186 - mcc: 0.9441 - auc_1: 0.9992 - val_loss: 0.2508 - val_accuracy: 0.9344 - val_precision_1: 0.9509 - val_recall_1: 0.9219 - val_f1_score: 0.9344 - val_specificity: 0.9995 - val_sensitivity: 0.9213 - val_mcc: 0.9345 - val_auc_1: 0.9947
# Epoch 3/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0933 - accuracy: 0.9803 - precision_1: 0.9865 - recall_1: 0.9701 - f1_score: 0.9764 - specificity: 0.9999 - sensitivity: 0.9692 - mcc: 0.9766 - auc_1: 0.9998 - val_loss: 0.2280 - val_accuracy: 0.9391 - val_precision_1: 0.9537 - val_recall_1: 0.9336 - val_f1_score: 0.9420 - val_specificity: 0.9995 - val_sensitivity: 0.9330 - val_mcc: 0.9419 - val_auc_1: 0.9947
# Epoch 4/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0594 - accuracy: 0.9881 - precision_1: 0.9931 - recall_1: 0.9826 - f1_score: 0.9863 - specificity: 0.9999 - sensitivity: 0.9817 - mcc: 0.9864 - auc_1: 0.9998 - val_loss: 0.3377 - val_accuracy: 0.9282 - val_precision_1: 0.9438 - val_recall_1: 0.9180 - val_f1_score: 0.9290 - val_specificity: 0.9995 - val_sensitivity: 0.9174 - val_mcc: 0.9290 - val_auc_1: 0.9895
# Epoch 5/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0682 - accuracy: 0.9844 - precision_1: 0.9903 - recall_1: 0.9785 - f1_score: 0.9827 - specificity: 0.9999 - sensitivity: 0.9776 - mcc: 0.9829 - auc_1: 0.9996 - val_loss: 0.3203 - val_accuracy: 0.9290 - val_precision_1: 0.9434 - val_recall_1: 0.9243 - val_f1_score: 0.9319 - val_specificity: 0.9994 - val_sensitivity: 0.9237 - val_mcc: 0.9318 - val_auc_1: 0.9880
# Epoch 6/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0546 - accuracy: 0.9887 - precision_1: 0.9910 - recall_1: 0.9853 - f1_score: 0.9868 - specificity: 0.9999 - sensitivity: 0.9844 - mcc: 0.9869 - auc_1: 0.9993 - val_loss: 0.3249 - val_accuracy: 0.9243 - val_precision_1: 0.9380 - val_recall_1: 0.9212 - val_f1_score: 0.9281 - val_specificity: 0.9994 - val_sensitivity: 0.9206 - val_mcc: 0.9279 - val_auc_1: 0.9896
# Epoch 7/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0498 - accuracy: 0.9883 - precision_1: 0.9933 - recall_1: 0.9859 - f1_score: 0.9882 - specificity: 0.9999 - sensitivity: 0.9850 - mcc: 0.9883 - auc_1: 0.9994 - val_loss: 0.3266 - val_accuracy: 0.9251 - val_precision_1: 0.9410 - val_recall_1: 0.9219 - val_f1_score: 0.9305 - val_specificity: 0.9994 - val_sensitivity: 0.9221 - val_mcc: 0.9303 - val_auc_1: 0.9912
# Epoch 8/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0442 - accuracy: 0.9902 - precision_1: 0.9927 - recall_1: 0.9857 - f1_score: 0.9879 - specificity: 0.9999 - sensitivity: 0.9848 - mcc: 0.9879 - auc_1: 0.9996 - val_loss: 0.2927 - val_accuracy: 0.9383 - val_precision_1: 0.9522 - val_recall_1: 0.9321 - val_f1_score: 0.9411 - val_specificity: 0.9995 - val_sensitivity: 0.9322 - val_mcc: 0.9410 - val_auc_1: 0.9892
# Epoch 9/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0381 - accuracy: 0.9904 - precision_1: 0.9931 - recall_1: 0.9879 - f1_score: 0.9892 - specificity: 0.9999 - sensitivity: 0.9869 - mcc: 0.9892 - auc_1: 0.9997 - val_loss: 0.3061 - val_accuracy: 0.9430 - val_precision_1: 0.9525 - val_recall_1: 0.9391 - val_f1_score: 0.9455 - val_specificity: 0.9995 - val_sensitivity: 0.9393 - val_mcc: 0.9453 - val_auc_1: 0.9877
# Epoch 10/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0436 - accuracy: 0.9893 - precision_1: 0.9917 - recall_1: 0.9855 - f1_score: 0.9873 - specificity: 0.9999 - sensitivity: 0.9846 - mcc: 0.9873 - auc_1: 0.9996 - val_loss: 0.3710 - val_accuracy: 0.9391 - val_precision_1: 0.9521 - val_recall_1: 0.9305 - val_f1_score: 0.9398 - val_specificity: 0.9995 - val_sensitivity: 0.9299 - val_mcc: 0.9398 - val_auc_1: 0.9876
# Epoch 11/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0589 - accuracy: 0.9846 - precision_1: 0.9892 - recall_1: 0.9824 - f1_score: 0.9845 - specificity: 0.9999 - sensitivity: 0.9815 - mcc: 0.9845 - auc_1: 0.9991 - val_loss: 0.3385 - val_accuracy: 0.9297 - val_precision_1: 0.9462 - val_recall_1: 0.9196 - val_f1_score: 0.9310 - val_specificity: 0.9995 - val_sensitivity: 0.9190 - val_mcc: 0.9311 - val_auc_1: 0.9888
# Epoch 12/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0273 - accuracy: 0.9924 - precision_1: 0.9963 - recall_1: 0.9910 - f1_score: 0.9923 - specificity: 1.0000 - sensitivity: 0.9900 - mcc: 0.9924 - auc_1: 0.9997 - val_loss: 0.3272 - val_accuracy: 0.9360 - val_precision_1: 0.9453 - val_recall_1: 0.9305 - val_f1_score: 0.9367 - val_specificity: 0.9995 - val_sensitivity: 0.9299 - val_mcc: 0.9366 - val_auc_1: 0.9885
# Epoch 13/50
# 854/854 [==============================] - 63s 74ms/step - loss: 0.0372 - accuracy: 0.9906 - precision_1: 0.9943 - recall_1: 0.9867 - f1_score: 0.9890 - specificity: 0.9999 - sensitivity: 0.9858 - mcc: 0.9891 - auc_1: 0.9994 - val_loss: 0.3305 - val_accuracy: 0.9415 - val_precision_1: 0.9538 - val_recall_1: 0.9352 - val_f1_score: 0.9428 - val_specificity: 0.9995 - val_sensitivity: 0.9346 - val_mcc: 0.9428 - val_auc_1: 0.9888
# Total training time: 858.8744207720001 seconds

# %%
# Calculate and print time
total_train_time = time_callback.total_train_time
epoch_times = time_callback.epoch_times.copy()

execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(total_train_time // unit[0])
    avg_value = int(np.mean(epoch_times) // unit[0]) if unit[0] != 0 else 0

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    total_train_time -= total_value * unit[0]
    epoch_times = [time - avg_value * unit[0] for time in epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 14 minutes, 18 seconds, 874 milliseconds
# Average time per epoch: 01 minutes, 05 seconds, 998 milliseconds

# %%
# Test the model against testing data
_ = model.evaluate(test_data)
# Out:
# 458/458 [==============================] - 10s 22ms/step - loss: 0.2404 - accuracy: 0.9406 - precision_1: 0.9517 - recall_1: 0.9344 - f1_score: 0.9422 - specificity: 0.9995 - sensitivity: 0.9345 - mcc: 0.9421 - auc_1: 0.9925

# %%
def plot_metrics(history, metric_name_list, figure_size=(10, 6)):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        history: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot
        figure_size: a tuple specifying the size of the figure (width, height)

    Returns:
        None
    """
    # Check if history is a valid Keras History object
    if not isinstance(history, type(tf.keras.callbacks.History())):
        raise ValueError("Invalid Keras History object provided.")

    num_metrics = len(metric_name_list)

    # Create subplots
    figure, axes = plt.subplots(num_metrics, figsize=(figure_size[0], figure_size[1] * num_metrics))

    # Define x-axis range
    rng = range(1, len(history.history[metric_name_list[0]]) + 1)

    for ax, metric_name in zip(axes, metric_name_list):
        # Check if the metric exists in the history
        if metric_name not in history.history:
            raise ValueError(f"Metric '{metric_name}' not found in the training history.")

        metric = history.history[metric_name]
        v_metric = history.history.get(f"val_{metric_name}", None)

        # Plot training metric
        ax.plot(rng, metric, label=metric_name)

        # Plot validation metric if available
        if v_metric is not None:
            ax.plot(rng, v_metric, label=f"val_{metric_name}")

        ax.legend()
        ax.set_xlabel("Epochs")

        # Set y-axis label and title
        ylabel = metric_name.upper() if metric_name in ("auc", "mcc") else metric_name.capitalize()
        ax.set_ylabel(ylabel)
        ax.set_title(f"{ylabel} vs Epochs")

        # Set y-axis limits
        max_loss = max(max(metric), max(v_metric)) if v_metric is not None else max(metric)
        min_loss = min(min(metric), min(v_metric)) if v_metric is not None else min(metric)
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()
    plt.show()

metric_names = ["loss", "accuracy", "precision_1", "recall_1", "f1_score",
                "specificity", "sensitivity", "mcc", "auc_1"]
plot_metrics(history, metric_names)

# %%
# Assuming you have a DataFrame 'df' with a 'labels' column
classes = df['labels'].unique()

# Convert predicted probabilities to class labels
predictions = model.predict(test_data)
predicted_labels = predictions.argmax(axis=1)

true_labels = test_data.classes
tests = len(true_labels)

# Calculate accuracy score
accuracy = accuracy_score(true_labels, predicted_labels)
accuracy_percentage = accuracy * 100

# Calculate the total number of errors
errors = np.sum(predicted_labels != true_labels)

# Print the classification report with class names and values in decimals
report = classification_report(true_labels, predicted_labels, target_names=classes, digits=4)

print(report)
print(f'There were {errors} errors in {tests} tests for an accuracy of {accuracy_percentage:6.2f}%')
# Out:
# 458/458 [==============================] - 9s 18ms/step
#                    precision    recall  f1-score   support
#
# BACKGROUND_Google     0.8537    0.7500    0.7985       140
#             Faces     1.0000    1.0000    1.0000       131
#        Faces_easy     1.0000    1.0000    1.0000       131
#          Leopards     0.9524    1.0000    0.9756        60
#        Motorbikes     1.0000    1.0000    1.0000       239
#         accordion     1.0000    1.0000    1.0000        16
#         airplanes     0.9917    1.0000    0.9959       240
#            anchor     0.8571    0.9231    0.8889        13
#               ant     0.7857    0.8462    0.8148        13
#            barrel     1.0000    0.7857    0.8800        14
#              bass     0.9231    0.7500    0.8276        16
#            beaver     1.0000    0.7857    0.8800        14
#         binocular     1.0000    0.9000    0.9474        10
#            bonsai     0.9474    0.9474    0.9474        38
#             brain     0.9355    1.0000    0.9667        29
#      brontosaurus     0.7778    0.5385    0.6364        13
#            buddha     0.9259    0.9615    0.9434        26
#         butterfly     0.8966    0.9630    0.9286        27
#            camera     0.8750    0.9333    0.9032        15
#            cannon     1.0000    0.8462    0.9167        13
#          car_side     1.0000    1.0000    1.0000        37
#       ceiling_fan     0.9333    1.0000    0.9655        14
#         cellphone     1.0000    0.9444    0.9714        18
#             chair     0.8500    0.8947    0.8718        19
#        chandelier     0.9688    0.9688    0.9688        32
#       cougar_body     1.0000    0.8571    0.9231        14
#       cougar_face     1.0000    1.0000    1.0000        21
#              crab     0.7917    0.8636    0.8261        22
#          crayfish     0.8333    0.7143    0.7692        21
#         crocodile     0.8235    0.9333    0.8750        15
#    crocodile_head     0.9286    0.8667    0.8966        15
#               cup     1.0000    1.0000    1.0000        17
#         dalmatian     0.9524    1.0000    0.9756        20
#       dollar_bill     0.9412    1.0000    0.9697        16
#           dolphin     1.0000    0.9000    0.9474        20
#         dragonfly     1.0000    0.9500    0.9744        20
#   electric_guitar     1.0000    1.0000    1.0000        23
#          elephant     0.4500    0.9474    0.6102        19
#               emu     1.0000    0.9375    0.9677        16
#         euphonium     1.0000    1.0000    1.0000        19
#              ewer     1.0000    1.0000    1.0000        26
#             ferry     1.0000    0.9500    0.9744        20
#          flamingo     0.9091    1.0000    0.9524        20
#     flamingo_head     0.8667    1.0000    0.9286        13
#          garfield     0.6923    0.9000    0.7826        10
#           gerenuk     1.0000    0.8000    0.8889        10
#        gramophone     1.0000    1.0000    1.0000        15
#       grand_piano     1.0000    1.0000    1.0000        30
#         hawksbill     1.0000    0.9333    0.9655        30
#         headphone     1.0000    0.8462    0.9167        13
#          hedgehog     0.9412    1.0000    0.9697        16
#        helicopter     0.9259    0.9615    0.9434        26
#              ibis     1.0000    0.9167    0.9565        24
#      inline_skate     1.0000    0.8889    0.9412         9
#       joshua_tree     0.7917    1.0000    0.8837        19
#          kangaroo     0.9259    0.9615    0.9434        26
#             ketch     0.9677    0.8824    0.9231        34
#              lamp     0.8824    0.8333    0.8571        18
#            laptop     1.0000    0.9583    0.9787        24
#             llama     0.9500    0.8261    0.8837        23
#           lobster     0.7778    0.5833    0.6667        12
#             lotus     0.6552    0.9500    0.7755        20
#          mandolin     1.0000    1.0000    1.0000        13
#            mayfly     0.9167    0.9167    0.9167        12
#           menorah     0.9630    1.0000    0.9811        26
#         metronome     1.0000    1.0000    1.0000        10
#           minaret     0.9583    1.0000    0.9787        23
#          nautilus     1.0000    1.0000    1.0000        17
#           octopus     1.0000    0.9000    0.9474        10
#             okapi     1.0000    1.0000    1.0000        12
#            pagoda     0.9333    1.0000    0.9655        14
#             panda     0.9000    0.8182    0.8571        11
#            pigeon     0.9167    0.8462    0.8800        13
#             pizza     1.0000    1.0000    1.0000        16
#          platypus     0.7500    0.9000    0.8182        10
#           pyramid     0.9444    1.0000    0.9714        17
#          revolver     0.8929    1.0000    0.9434        25
#             rhino     1.0000    0.5000    0.6667        18
#           rooster     0.9375    1.0000    0.9677        15
#         saxophone     1.0000    0.9167    0.9565        12
#          schooner     0.8571    0.9474    0.9000        19
#          scissors     1.0000    0.8333    0.9091        12
#          scorpion     0.9231    0.9600    0.9412        25
#         sea_horse     0.8750    0.8235    0.8485        17
#            snoopy     0.5000    1.0000    0.6667        10
#       soccer_ball     1.0000    1.0000    1.0000        19
#           stapler     1.0000    1.0000    1.0000        13
#          starfish     0.9630    1.0000    0.9811        26
#       stegosaurus     0.8947    0.9444    0.9189        18
#         stop_sign     0.9048    1.0000    0.9500        19
#        strawberry     1.0000    0.8000    0.8889        10
#         sunflower     0.9630    1.0000    0.9811        26
#              tick     0.9375    1.0000    0.9677        15
#         trilobite     0.9630    1.0000    0.9811        26
#          umbrella     0.9091    0.8696    0.8889        23
#             watch     0.9595    0.9861    0.9726        72
#       water_lilly     1.0000    0.1818    0.3077        11
#        wheelchair     1.0000    0.9444    0.9714        18
#          wild_cat     1.0000    0.7000    0.8235        10
#     windsor_chair     0.9444    1.0000    0.9714        17
#            wrench     0.9091    0.8333    0.8696        12
#          yin_yang     1.0000    0.9444    0.9714        18
#
#          accuracy                         0.9406      2744
#         macro avg     0.9323    0.9163    0.9162      2744
#      weighted avg     0.9482    0.9406    0.9401      2744
#
# There were 163 errors in 2744 tests for an accuracy of  94.06%
